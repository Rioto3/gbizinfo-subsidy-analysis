# %% [markdown]
# ## 初期設定

# %%
# APIの基本設定
API_TOKEN = "YOUR_API_TOKEN"  # 実際のAPIトークンに置き換えてください
API_TOKEN = "Hgt7Gj3Il3rQovE8OiU817jgmrKe9jnM"  # テスト後に削除
BASE_URL = "https://info.gbiz.go.jp/hojin"
HEADERS = {"X-hojinInfo-api-token": API_TOKEN}

# APIリクエストの間隔（秒）- レート制限対策
REQUEST_INTERVAL = 0.5

print("API設定が完了しました")
print(f"Base URL: {BASE_URL}")
# Out:
# API設定が完了しました
# Base URL: https://info.gbiz.go.jp/hojin

# %% [markdown]
# ## 初期実行

# %%
from pprint import pprint
import requests

def get_subsidy_data():
   """
   gBizINFO APIから補助金情報を取得する関数
   """
   endpoint = f"{BASE_URL}/v1/hojin/updateInfo/subsidy"
   
   params = {
       'from': '20200401',
       'to': '20210331',
       'page': '1'
   }
   
   try:
       response = requests.get(endpoint, headers=HEADERS, params=params)
       
       if response.status_code == 200:
           return response.json()
       else:
           print(f"エラー: HTTPステータスコード {response.status_code}")
           print(f"レスポンス: {response.text}")
           return None
   except Exception as e:
       print(f"例外が発生しました: {e}")
       return None

# メイン処理
if __name__ == "__main__":
   print("gBizINFO APIから2020年度の補助金情報を取得しています...")
   data = get_subsidy_data()
   
   if data and "hojin-infos" in data:
      print(f"総件数: {data.get('totalCount', '不明')}")
      print(f"総ページ数: {data.get('totalPage', '不明')}")
       
       # 最初の5件のみ表示
      print("\n最初の1件の補助金データ:")
      pprint(data["hojin-infos"][0])
   else:
      print("データが取得できませんでした")
# Out:
# gBizINFO APIから2020年度の補助金情報を取得しています...
# 総件数: 91892
# 総ページ数: 919
#
# 最初の1件の補助金データ:
# {'corporate_number': '1000020470007',
#  'kana': 'おきなわけん',
#  'location': '沖縄県那覇市泉崎１丁目２－２',
#  'name': '沖縄県',
#  'name_en': 'Okinawa Prefectural Government',
#  'postal_code': '9000021',
#  'status': '-',
#  'subsidy': [{'amount': '6397000',
#               'date_of_approval': '2020-07-08',
#               'government_departments': '防衛省',
#               'joint_signatures': None,
#               'note': None,
#               'subsidy_resource': None,
#               'target': None,
#               'title': '美咲特別支援学校防音事業（実施設計）'},
#              {'amount': '2578000',
#               'date_of_approval': '2020-06-04',
#               'government_departments': '防衛省',
#               'joint_signatures': None,
#               'note': None,
#               'subsidy_resource': None,
#               'target': None,
#               'title': 'コザ高等学校防音事業（実施設計）'},
#              {'amount': '68977000',
#               'date_of_approval': '2020-03-18',
#               'government_departments': '防衛省',
#               'joint_signatures': None,
#               'note': None,
#               'subsidy_resource': None,
#               'target': None,
#               'title': '美里工業高等学校防音事業'},
#              {'amount': '94321000',
#               'date_of_approval': '2020-03-17',
#               'government_departments': '防衛省',
#               'joint_signatures': None,
#               'note': None,
#               'subsidy_resource': None,
#               'target': None,
#               'title': '前原高等学校防音事業'}],
#  'update_date': '2018-04-04T00:00:00+09:00'}

# %% [markdown]
# ## DB用意

# %% [markdown]
# #### sqlite3_magic 定義

# %%
from IPython.core.magic import register_cell_magic
import sqlite3
import pandas as pd

# グローバル変数としてコネクションを保持
_conn = None
_cursor = None

@register_cell_magic
def sql(line, cell):
    """
    SQLiteクエリを実行するセルマジック
    使用例:
    # %%sql sqlite:///miyagi_data.db
    SELECT * FROM table WHERE condition
    または接続済みの場合:
    # %%sql
    SELECT * FROM table WHERE condition
    """
    global _conn, _cursor
    
    # 接続情報が指定されているか確認
    if line and line.startswith('sqlite:///'):
        db_path = line.replace('sqlite:///', '')
        if _conn:
            _conn.close()
        _conn = sqlite3.connect(db_path)
        _cursor = _conn.cursor()
        return f"{db_path} に接続しました"
        
    # 接続確認
    if not _conn or not _cursor:
        return "エラー: 最初に '%%sql sqlite:///ファイル名.db' で接続してください"
        
    try:
        if cell.lower().strip().startswith(('select', 'with')):
            # Pandasを使用して結果を表形式で表示
            df = pd.read_sql_query(cell, _conn)
            return df
        else:
            _cursor.execute(cell)
            _conn.commit()
            return "クエリを実行しました"
    except Exception as e:
        return f"エラー: {e}"

# %% [markdown]
# #### sqlite3_magic 接続

# %%
# %%sql sqlite:///gbiz.sqlite3
# select name from sqlite_master where type='table'
# Out:
# 'gbiz.sqlite3 に接続しました'

# %% [markdown]
# #### テーブル作成

# %% [markdown]
# 法人テーブル

# %%
# %%sql
# CREATE TABLE IF NOT EXISTS companies (
#     corporate_number TEXT PRIMARY KEY,
#     name TEXT,
#     kana TEXT,
#     name_en TEXT,
#     location TEXT,
#     postal_code TEXT,
#     status TEXT,
#     fiscal_year INTEGER,
#     update_date TEXT
# );
# Out:
# 'クエリを実行しました'

# %% [markdown]
# 補助金テーブル

# %%
# %%sql
# CREATE TABLE IF NOT EXISTS subsidies (
#     id INTEGER PRIMARY KEY,
#     corporate_number TEXT,
#     title TEXT,
#     amount TEXT,
#     date_of_approval TEXT,
#     government_departments TEXT,
#     subsidy_resource TEXT,
#     target TEXT,
#     note TEXT,
#     fiscal_year INTEGER,
#     FOREIGN KEY (corporate_number) REFERENCES companies(corporate_number)
# );
# Out:
# 'クエリを実行しました'

# %%
# %%sql
# select name from sqlite_master where type='table';
# Out:
#               name
# 0        companies
# 1        subsidies
# 2  sqlite_sequence
# 3  processed_pages

# %%
# %%sql
# select count(*) from subsidies
# Out:
#    count(*)
# 0    231007

# %% [markdown]
# ## 関数実装

# %%
import sqlite3
import aiohttp
import asyncio
import time

def period(fiscal_year):
    """年度から期間（開始日・終了日）を返す"""
    from_date = f"{fiscal_year}0401"
    to_date = f"{fiscal_year+1}0331"
    return from_date, to_date

def setup_database(conn):
    """データベーススキーマ設定（fiscal_yearカラム追加）"""
    cursor = conn.cursor()
    
    # 企業テーブル
    cursor.execute('''
    CREATE TABLE IF NOT EXISTS companies (
        corporate_number TEXT,
        name TEXT,
        kana TEXT,
        name_en TEXT,
        location TEXT,
        postal_code TEXT,
        status TEXT,
        update_date TEXT,
        fiscal_year INTEGER,
        PRIMARY KEY (corporate_number, fiscal_year)
    )
    ''')
    
    # 補助金テーブル
    cursor.execute('''
    CREATE TABLE IF NOT EXISTS subsidies (
        id INTEGER PRIMARY KEY AUTOINCREMENT,
        corporate_number TEXT,
        title TEXT,
        amount TEXT,
        date_of_approval TEXT,
        government_departments TEXT,
        subsidy_resource TEXT,
        target TEXT,
        note TEXT,
        fiscal_year INTEGER,
        FOREIGN KEY (corporate_number, fiscal_year) REFERENCES companies(corporate_number, fiscal_year)
    )
    ''')
    
    # 処理済みページ記録テーブル
    cursor.execute('''
    CREATE TABLE IF NOT EXISTS processed_pages (
        data_type TEXT,
        page_number INTEGER,
        fiscal_year INTEGER,
        PRIMARY KEY (data_type, page_number, fiscal_year)
    )
    ''')
    
    conn.commit()
    return conn

async def fetch_subsidy_data(session, from_date=None, to_date=None, page=1):
    """非同期APIリクエスト - 補助金情報取得"""
    endpoint = f"{BASE_URL}/v1/hojin/updateInfo/subsidy"
    params = {
        'from': from_date,
        'to': to_date,
        'page': str(page)
    }
    
    try:
        async with session.get(endpoint, headers=HEADERS, params=params) as response:
            if response.status == 200:
                return await response.json()
            else:
                print(f"エラー: HTTPステータスコード {response.status}")
                return None
    except Exception as e:
        print(f"リクエストエラー: {e}")
        return None

def save_data_to_db(conn, data, fiscal_year):
    """データベースにデータを保存"""
    if not data or "hojin-infos" not in data:
        return 0, 0
    
    cursor = conn.cursor()
    companies_count = 0
    subsidies_count = 0
    
    for company in data["hojin-infos"]:
        # 法人情報の保存
        cursor.execute('''
        INSERT OR REPLACE INTO companies 
        VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
        ''', (
            company.get("corporate_number", ""),
            company.get("name", ""),
            company.get("kana", ""),
            company.get("name_en", ""),
            company.get("location", ""),
            company.get("postal_code", ""),
            company.get("status", ""),
            company.get("update_date", ""),
            fiscal_year
        ))
        companies_count += cursor.rowcount
        
        # 補助金情報の保存
        if "subsidy" in company and company["subsidy"]:
            for subsidy in company["subsidy"]:
                cursor.execute('''
                INSERT INTO subsidies 
                VALUES (NULL, ?, ?, ?, ?, ?, ?, ?, ?, ?)
                ''', (
                    company.get("corporate_number", ""),
                    subsidy.get("title", ""),
                    subsidy.get("amount", ""),
                    subsidy.get("date_of_approval", ""),
                    subsidy.get("government_departments", ""),
                    subsidy.get("subsidy_resource", ""),
                    subsidy.get("target", ""),
                    subsidy.get("note", ""),
                    fiscal_year
                ))
                subsidies_count += 1
    
    conn.commit()
    return companies_count, subsidies_count

def is_page_processed(conn, page, fiscal_year):
    """ページが処理済みかチェック"""
    cursor = conn.cursor()
    cursor.execute(
        'SELECT 1 FROM processed_pages WHERE data_type = ? AND page_number = ? AND fiscal_year = ?', 
        ('subsidy', page, fiscal_year)
    )
    return cursor.fetchone() is not None

def mark_page_processed(conn, page, fiscal_year):
    """ページを処理済みとしてマーク"""
    cursor = conn.cursor()
    cursor.execute(
        'INSERT OR IGNORE INTO processed_pages VALUES (?, ?, ?)', 
        ('subsidy', page, fiscal_year)
    )
    conn.commit()

async def get_subsidy_data_prod(from_date=None, to_date=None, fiscal_year=2020, db_connect=None):
    """非同期実行で全国の補助金情報を取得"""
    if from_date is None or to_date is None:
        from_date, to_date = period(fiscal_year)
    
    conn = db_connect if db_connect is not None else sqlite3.connect('gbiz.sqlite3')
    setup_database(conn)
    
    async with aiohttp.ClientSession() as session:
        # 最初に1ページ目を取得して総ページ数を確認
        initial_data = await fetch_subsidy_data(session, from_date, to_date, 1)
        if not initial_data or "totalPage" not in initial_data:
            print("総ページ数の取得に失敗しました")
            return
        
        total_pages = int(initial_data["totalPage"])
        print(f"補助金情報総ページ数: {total_pages}、期間: {from_date}～{to_date}、年度: {fiscal_year}")
        
        # 1ページ目の処理
        if not is_page_processed(conn, 1, fiscal_year):
            companies, subsidies = save_data_to_db(conn, initial_data, fiscal_year)
            mark_page_processed(conn, 1, fiscal_year)
            print(f"ページ 1: {companies}社の情報と{subsidies}件の補助金情報を保存")
        else:
            print("ページ 1は処理済みです")
        
        # 残りのページを10ページずつバッチ処理
        total_companies = 0
        total_subsidies = 0
        processed_pages = 1
        start_time = time.time()
        
        for start_page in range(2, total_pages + 1, 10):
            batch_tasks = []
            batch_pages = []
            
            for page in range(start_page, min(start_page + 10, total_pages + 1)):
                if not is_page_processed(conn, page, fiscal_year):
                    batch_tasks.append(fetch_subsidy_data(session, from_date, to_date, page))
                    batch_pages.append(page)
                else:
                    print(f"ページ {page} は処理済みです")
            
            if batch_tasks:
                print(f"バッチ取得: {len(batch_tasks)} ページ")
                results = await asyncio.gather(*batch_tasks)
                
                for i, result in enumerate(results):
                    page = batch_pages[i]
                    if result:
                        companies, subsidies = save_data_to_db(conn, result, fiscal_year)
                        mark_page_processed(conn, page, fiscal_year)
                        total_companies += companies
                        total_subsidies += subsidies
                        processed_pages += 1
                        
                        # 進捗表示
                        elapsed_time = time.time() - start_time
                        avg_time_per_page = elapsed_time / processed_pages if processed_pages > 0 else 0
                        remaining_pages = total_pages - processed_pages
                        est_remaining_time = avg_time_per_page * remaining_pages
                        
                        print(f"ページ {page}/{total_pages}: {companies}社, {subsidies}件 " +
                              f"(進捗: {processed_pages/total_pages*100:.1f}%, 残り約{est_remaining_time/60:.1f}分)")
                
                await asyncio.sleep(1)  # APIレート制限対策
    
    # 最終結果の表示
    cursor = conn.cursor()
    cursor.execute("SELECT COUNT(*) FROM companies WHERE fiscal_year = ?", (fiscal_year,))
    total_companies = cursor.fetchone()[0]
    cursor.execute("SELECT COUNT(*) FROM subsidies WHERE fiscal_year = ?", (fiscal_year,))
    total_subsidies = cursor.fetchone()[0]
    
    elapsed_time = time.time() - start_time
    print(f"\n処理完了 ({elapsed_time/60:.1f}分): {fiscal_year}年度データ")
    print(f"データベースには{total_companies}社の法人情報と{total_subsidies}件の補助金情報があります")

# %%
"""
Done:
2023,
"""

# メイン処理
if __name__ == "__main__":
    
    fiscal_year = 2020
    from_date, to_date = period(fiscal_year)
    print(f"{fiscal_year}年度({from_date}～{to_date})の補助金データを取得します...")
    
    connect = sqlite3.connect('gbiz.sqlite3')

    await get_subsidy_data_prod(from_date=from_date, to_date=to_date, fiscal_year=fiscal_year, db_connect=connect)
# Out:
# 2023年度(20230401～20240331)の補助金データを取得します...
# 補助金情報総ページ数: 2312、期間: 20230401～20240331、年度: 2023
# ページ 1は処理済みです
# ページ 2 は処理済みです
# ページ 3 は処理済みです
# ページ 4 は処理済みです
# ページ 5 は処理済みです
# ページ 6 は処理済みです
# ページ 7 は処理済みです
# ページ 8 は処理済みです
# ページ 9 は処理済みです
# ページ 10 は処理済みです
# ページ 11 は処理済みです
# ページ 12 は処理済みです
# ページ 13 は処理済みです
# ページ 14 は処理済みです
# ページ 15 は処理済みです
# ページ 16 は処理済みです
# ページ 17 は処理済みです
# ページ 18 は処理済みです
# ページ 19 は処理済みです
# ページ 20 は処理済みです
# ページ 21 は処理済みです
# ページ 22 は処理済みです
# ページ 23 は処理済みです
# ページ 24 は処理済みです
# ページ 25 は処理済みです
# ページ 26 は処理済みです
# ページ 27 は処理済みです
# ページ 28 は処理済みです
# ページ 29 は処理済みです
# ページ 30 は処理済みです
# ページ 31 は処理済みです
# ページ 32 は処理済みです
# ページ 33 は処理済みです
# ページ 34 は処理済みです
# ページ 35 は処理済みです
# ページ 36 は処理済みです
# ページ 37 は処理済みです
# ページ 38 は処理済みです
# ページ 39 は処理済みです
# ページ 40 は処理済みです
# ページ 41 は処理済みです
# ページ 42 は処理済みです
# ページ 43 は処理済みです
# ページ 44 は処理済みです
# ページ 45 は処理済みです
# ページ 46 は処理済みです
# ページ 47 は処理済みです
# ページ 48 は処理済みです
# ページ 49 は処理済みです
# ページ 50 は処理済みです
# ページ 51 は処理済みです
# ページ 52 は処理済みです
# ページ 53 は処理済みです
# ページ 54 は処理済みです
# ページ 55 は処理済みです
# ページ 56 は処理済みです
# ページ 57 は処理済みです
# ページ 58 は処理済みです
# ページ 59 は処理済みです
# ページ 60 は処理済みです
# ページ 61 は処理済みです
# ページ 62 は処理済みです
# ページ 63 は処理済みです
# ページ 64 は処理済みです
# ページ 65 は処理済みです
# ページ 66 は処理済みです
# ページ 67 は処理済みです
# ページ 68 は処理済みです
# ページ 69 は処理済みです
# ページ 70 は処理済みです
# ページ 71 は処理済みです
# ページ 72 は処理済みです
# ページ 73 は処理済みです
# ページ 74 は処理済みです
# ページ 75 は処理済みです
# ページ 76 は処理済みです
# ページ 77 は処理済みです
# ページ 78 は処理済みです
# ページ 79 は処理済みです
# ページ 80 は処理済みです
# ページ 81 は処理済みです
# ページ 82 は処理済みです
# ページ 83 は処理済みです
# ページ 84 は処理済みです
# ページ 85 は処理済みです
# ページ 86 は処理済みです
# ページ 87 は処理済みです
# ページ 88 は処理済みです
# ページ 89 は処理済みです
# ページ 90 は処理済みです
# ページ 91 は処理済みです
# ページ 92 は処理済みです
# ページ 93 は処理済みです
# ページ 94 は処理済みです
# ページ 95 は処理済みです
# ページ 96 は処理済みです
# ページ 97 は処理済みです
# ページ 98 は処理済みです
# ページ 99 は処理済みです
# ページ 100 は処理済みです
# ページ 101 は処理済みです
# ページ 102 は処理済みです
# ページ 103 は処理済みです
# ページ 104 は処理済みです
# ページ 105 は処理済みです
# ページ 106 は処理済みです
# ページ 107 は処理済みです
# ページ 108 は処理済みです
# ページ 109 は処理済みです
# ページ 110 は処理済みです
# ページ 111 は処理済みです
# ページ 112 は処理済みです
# ページ 113 は処理済みです
# ページ 114 は処理済みです
# ページ 115 は処理済みです
# ページ 116 は処理済みです
# ページ 117 は処理済みです
# ページ 118 は処理済みです
# ページ 119 は処理済みです
# ページ 988 は処理済みです
# ページ 989 は処理済みです
# ページ 990 は処理済みです
# ページ 991 は処理済みです
# ページ 992 は処理済みです
# ページ 993 は処理済みです
# ページ 994 は処理済みです
# ページ 995 は処理済みです
# ページ 996 は処理済みです
# ページ 997 は処理済みです
# ページ 998 は処理済みです
# ページ 999 は処理済みです
# ページ 1000 は処理済みです
# ページ 1001 は処理済みです
# ページ 1002 は処理済みです
# ページ 1003 は処理済みです
# ページ 1004 は処理済みです
# ページ 1005 は処理済みです
# ページ 1006 は処理済みです
# ページ 1007 は処理済みです
# ページ 1008 は処理済みです
# ページ 1009 は処理済みです
# ページ 1010 は処理済みです
# ページ 1011 は処理済みです
# ページ 1012 は処理済みです
# ページ 1013 は処理済みです
# ページ 1014 は処理済みです
# ページ 1015 は処理済みです
# ページ 1016 は処理済みです
# ページ 1017 は処理済みです
# ページ 1018 は処理済みです
# ページ 1019 は処理済みです
# ページ 1020 は処理済みです
# ページ 1021 は処理済みです
# ページ 1022 は処理済みです
# ページ 1023 は処理済みです
# ページ 1024 は処理済みです
# ページ 1025 は処理済みです
# ページ 1026 は処理済みです
# ページ 1027 は処理済みです
# ページ 1028 は処理済みです
# ページ 1029 は処理済みです
# ページ 1030 は処理済みです
# ページ 1031 は処理済みです
# ページ 1032 は処理済みです
# ページ 1033 は処理済みです
# ページ 1034 は処理済みです
# ページ 1035 は処理済みです
# ページ 1036 は処理済みです
# ページ 1037 は処理済みです
# ページ 1038 は処理済みです
# ページ 1039 は処理済みです
# ページ 1040 は処理済みです
# ページ 1041 は処理済みです
# ページ 1042 は処理済みです
# ページ 1043 は処理済みです
# ページ 1044 は処理済みです
# ページ 1045 は処理済みです
# ページ 1046 は処理済みです
# ページ 1047 は処理済みです
# ページ 1048 は処理済みです
# ページ 1049 は処理済みです
# ページ 1050 は処理済みです
# ページ 1051 は処理済みです
# ページ 1052 は処理済みです
# ページ 1053 は処理済みです
# ページ 1054 は処理済みです
# ページ 1055 は処理済みです
# ページ 1056 は処理済みです
# ページ 1057 は処理済みです
# ページ 1058 は処理済みです
# ページ 1059 は処理済みです
# ページ 1060 は処理済みです
# ページ 1061 は処理済みです
# ページ 1062 は処理済みです
# ページ 1063 は処理済みです
# ページ 1064 は処理済みです
# ページ 1065 は処理済みです
# ページ 1066 は処理済みです
# ページ 1067 は処理済みです
# ページ 1068 は処理済みです
# ページ 1069 は処理済みです
# ページ 1070 は処理済みです
# ページ 1071 は処理済みです
# ページ 1072 は処理済みです
# ページ 1073 は処理済みです
# ページ 1074 は処理済みです
# ページ 1075 は処理済みです
# ページ 1076 は処理済みです
# ページ 1077 は処理済みです
# ページ 1078 は処理済みです
# ページ 1079 は処理済みです
# ページ 1080 は処理済みです
# ページ 1081 は処理済みです
# ページ 1082 は処理済みです
# ページ 1083 は処理済みです
# ページ 1084 は処理済みです
# ページ 1085 は処理済みです
# ページ 1086 は処理済みです
# ページ 1087 は処理済みです
# ページ 1088 は処理済みです
# ページ 1089 は処理済みです
# ページ 1090 は処理済みです
# ページ 1091 は処理済みです
# ページ 1092 は処理済みです
# ページ 1093 は処理済みです
# ページ 1094 は処理済みです
# ページ 1095 は処理済みです
# ページ 1096 は処理済みです
# ページ 1097 は処理済みです
# ページ 1098 は処理済みです
# ページ 1099 は処理済みです
# ページ 1100 は処理済みです
# ページ 1101 は処理済みです
# ページ 1102 は処理済みです
# ページ 1103 は処理済みです
# ページ 1104 は処理済みです
# ページ 1105 は処理済みです
# ページ 1106 は処理済みです
# ページ 1107 は処理済みです
# ページ 1108 は処理済みです
# ページ 1109 は処理済みです
# ページ 1110 は処理済みです
# ページ 1111 は処理済みです
# ページ 1112 は処理済みです
# ページ 1113 は処理済みです
# ページ 1114 は処理済みです
# ページ 1115 は処理済みです
# ページ 1116 は処理済みです
# ページ 1117 は処理済みです
# ページ 1118 は処理済みです
# ページ 1119 は処理済みです
# ページ 1120 は処理済みです
# ページ 1121 は処理済みです
# ページ 1122 は処理済みです
# ページ 1123 は処理済みです
# ページ 1124 は処理済みです
# ページ 1125 は処理済みです
# ページ 1126 は処理済みです
# ページ 1127 は処理済みです
# ページ 1128 は処理済みです
# ページ 1129 は処理済みです
# ページ 1130 は処理済みです
# ページ 1131 は処理済みです
# ページ 1132 は処理済みです
# ページ 1133 は処理済みです
# ページ 1134 は処理済みです
# ページ 1135 は処理済みです
# ページ 1136 は処理済みです
# ページ 1137 は処理済みです
# ページ 1138 は処理済みです
# ページ 1139 は処理済みです
# ページ 1140 は処理済みです
# ページ 1141 は処理済みです
# ページ 1142 は処理済みです
# ページ 1143 は処理済みです
# ページ 1144 は処理済みです
# ページ 1145 は処理済みです
# ページ 1146 は処理済みです
# ページ 1147 は処理済みです
# ページ 1148 は処理済みです
# ページ 1149 は処理済みです
# ページ 1150 は処理済みです
# ページ 1151 は処理済みです
# ページ 1152 は処理済みです
# ページ 1153 は処理済みです
# ページ 1154 は処理済みです
# ページ 1155 は処理済みです
# ページ 1156 は処理済みです
# ページ 1157 は処理済みです
# ページ 1158 は処理済みです
# ページ 1159 は処理済みです
# ページ 1160 は処理済みです
# ページ 1161 は処理済みです
# ページ 1162 は処理済みです
# ページ 1163 は処理済みです
# ページ 1164 は処理済みです
# ページ 1165 は処理済みです
# ページ 1166 は処理済みです
# ページ 1167 は処理済みです
# ページ 1168 は処理済みです
# ページ 1169 は処理済みです
# ページ 1170 は処理済みです
# ページ 1171 は処理済みです
# ページ 1172 は処理済みです
# ページ 1173 は処理済みです
# ページ 1174 は処理済みです
# ページ 1175 は処理済みです
# ページ 1176 は処理済みです
# ページ 1177 は処理済みです
# ページ 1178 は処理済みです
# ページ 1179 は処理済みです
# ページ 1180 は処理済みです
# ページ 1181 は処理済みです
# ページ 1182 は処理済みです
# ページ 1183 は処理済みです
# ページ 1184 は処理済みです
# ページ 1185 は処理済みです
# ページ 1186 は処理済みです
# ページ 1187 は処理済みです
# ページ 1188 は処理済みです
# ページ 1189 は処理済みです
# ページ 1190 は処理済みです
# ページ 1191 は処理済みです
# ページ 1192 は処理済みです
# ページ 1193 は処理済みです
# ページ 1194 は処理済みです
# ページ 1195 は処理済みです
# ページ 1196 は処理済みです
# ページ 1197 は処理済みです
# ページ 1198 は処理済みです
# ページ 1199 は処理済みです
# ページ 1200 は処理済みです
# ページ 1201 は処理済みです
# バッチ取得: 10 ページ
# ページ 1202/2312: 100社, 100件 (進捗: 0.1%, 残り約107.5分)
# ページ 1203/2312: 100社, 100件 (進捗: 0.2%, 残り約80.6分)
# ページ 1204/2312: 100社, 100件 (進捗: 0.2%, 残り約64.5分)
# ページ 1205/2312: 95社, 100件 (進捗: 0.3%, 残り約53.8分)
# ページ 1206/2312: 98社, 100件 (進捗: 0.3%, 残り約46.1分)
# ページ 1207/2312: 100社, 100件 (進捗: 0.3%, 残り約40.3分)
# ページ 1208/2312: 100社, 100件 (進捗: 0.4%, 残り約35.9分)
# ページ 1209/2312: 100社, 100件 (進捗: 0.4%, 残り約32.3分)
# ページ 1210/2312: 100社, 100件 (進捗: 0.5%, 残り約29.3分)
# ページ 1211/2312: 100社, 100件 (進捗: 0.5%, 残り約26.9分)
# バッチ取得: 10 ページ
# ページ 1212/2312: 100社, 100件 (進捗: 0.6%, 残り約46.6分)
# ページ 1213/2312: 100社, 100件 (進捗: 0.6%, 残り約43.3分)
# ページ 1214/2312: 100社, 100件 (進捗: 0.6%, 残り約40.4分)
# ページ 1215/2312: 100社, 100件 (進捗: 0.7%, 残り約37.8分)
# ページ 1216/2312: 99社, 100件 (進捗: 0.7%, 残り約35.6分)
# ページ 1217/2312: 96社, 100件 (進捗: 0.8%, 残り約33.6分)
# ページ 1218/2312: 92社, 100件 (進捗: 0.8%, 残り約31.9分)
# ページ 1219/2312: 99社, 100件 (進捗: 0.9%, 残り約30.3分)
# ページ 1220/2312: 100社, 100件 (進捗: 0.9%, 残り約28.8分)
# ページ 1221/2312: 100社, 100件 (進捗: 1.0%, 残り約27.5分)
# バッチ取得: 10 ページ
# ページ 1222/2312: 100社, 100件 (進捗: 1.0%, 残り約35.8分)
# ページ 1223/2312: 100社, 100件 (進捗: 1.0%, 残り約34.3分)
# ページ 1224/2312: 97社, 100件 (進捗: 1.1%, 残り約33.0分)
# ページ 1225/2312: 100社, 100件 (進捗: 1.1%, 残り約31.7分)
# ページ 1226/2312: 100社, 100件 (進捗: 1.2%, 残り約30.5分)
# ページ 1227/2312: 90社, 100件 (進捗: 1.2%, 残り約29.4分)
# ページ 1228/2312: 100社, 100件 (進捗: 1.3%, 残り約28.4分)
# ページ 1229/2312: 77社, 100件 (進捗: 1.3%, 残り約27.4分)
# ページ 1230/2312: 88社, 100件 (進捗: 1.3%, 残り約26.5分)
# ページ 1231/2312: 78社, 100件 (進捗: 1.4%, 残り約25.7分)
# バッチ取得: 10 ページ
# ページ 1232/2312: 63社, 100件 (進捗: 1.4%, 残り約31.4分)
# ページ 1233/2312: 68社, 100件 (進捗: 1.5%, 残り約30.4分)
# ページ 1234/2312: 74社, 100件 (進捗: 1.5%, 残り約29.6分)
# ページ 1235/2312: 69社, 100件 (進捗: 1.6%, 残り約28.7分)
# ページ 1236/2312: 81社, 100件 (進捗: 1.6%, 残り約28.0分)
# ページ 1237/2312: 100社, 100件 (進捗: 1.6%, 残り約27.2分)
# ページ 1238/2312: 100社, 100件 (進捗: 1.7%, 残り約26.5分)
# ページ 1239/2312: 87社, 100件 (進捗: 1.7%, 残り約25.8分)
# ページ 1240/2312: 100社, 100件 (進捗: 1.8%, 残り約25.2分)
# ページ 1241/2312: 100社, 100件 (進捗: 1.8%, 残り約24.6分)
# バッチ取得: 10 ページ
# ページ 1242/2312: 100社, 100件 (進捗: 1.9%, 残り約29.1分)
# ページ 1243/2312: 100社, 100件 (進捗: 1.9%, 残り約28.4分)
# ページ 1244/2312: 92社, 100件 (進捗: 1.9%, 残り約27.7分)
# ページ 1245/2312: 100社, 100件 (進捗: 2.0%, 残り約27.1分)
# ページ 1246/2312: 100社, 100件 (進捗: 2.0%, 残り約26.5分)
# ページ 1247/2312: 100社, 100件 (進捗: 2.1%, 残り約26.0分)
# ページ 1248/2312: 100社, 100件 (進捗: 2.1%, 残り約25.4分)
# ページ 1249/2312: 100社, 100件 (進捗: 2.2%, 残り約24.9分)
# ページ 1250/2312: 100社, 100件 (進捗: 2.2%, 残り約24.4分)
# ページ 1251/2312: 100社, 100件 (進捗: 2.2%, 残り約24.0分)
# バッチ取得: 10 ページ
# ページ 1252/2312: 96社, 100件 (進捗: 2.3%, 残り約27.6分)
# ページ 1253/2312: 96社, 100件 (進捗: 2.3%, 残り約27.0分)
# ページ 1254/2312: 100社, 100件 (進捗: 2.4%, 残り約26.5分)
# ページ 1255/2312: 100社, 100件 (進捗: 2.4%, 残り約26.1分)
# ページ 1256/2312: 87社, 100件 (進捗: 2.5%, 残り約25.6分)
# ページ 1257/2312: 100社, 100件 (進捗: 2.5%, 残り約25.1分)
# ページ 1258/2312: 100社, 100件 (進捗: 2.6%, 残り約24.7分)
# ページ 1259/2312: 100社, 100件 (進捗: 2.6%, 残り約24.3分)
# ページ 1260/2312: 100社, 100件 (進捗: 2.6%, 残り約23.9分)
# ページ 1261/2312: 98社, 100件 (進捗: 2.7%, 残り約23.5分)
# バッチ取得: 10 ページ
# ページ 1262/2312: 75社, 100件 (進捗: 2.7%, 残り約26.5分)
# ページ 1263/2312: 96社, 100件 (進捗: 2.8%, 残り約26.0分)
# ページ 1264/2312: 96社, 100件 (進捗: 2.8%, 残り約25.6分)
# ページ 1265/2312: 100社, 100件 (進捗: 2.9%, 残り約25.2分)
# ページ 1266/2312: 100社, 100件 (進捗: 2.9%, 残り約24.8分)
# ページ 1267/2312: 100社, 100件 (進捗: 2.9%, 残り約24.5分)
# ページ 1268/2312: 100社, 100件 (進捗: 3.0%, 残り約24.1分)
# ページ 1269/2312: 100社, 100件 (進捗: 3.0%, 残り約23.7分)
# ページ 1270/2312: 100社, 100件 (進捗: 3.1%, 残り約23.4分)
# ページ 1271/2312: 92社, 100件 (進捗: 3.1%, 残り約23.1分)
# バッチ取得: 10 ページ
# ページ 1272/2312: 100社, 100件 (進捗: 3.2%, 残り約25.6分)
# ページ 1273/2312: 98社, 100件 (進捗: 3.2%, 残り約25.2分)
# ページ 1274/2312: 80社, 100件 (進捗: 3.2%, 残り約24.9分)
# ページ 1275/2312: 62社, 100件 (進捗: 3.3%, 残り約24.6分)
# ページ 1276/2312: 100社, 100件 (進捗: 3.3%, 残り約24.2分)
# ページ 1277/2312: 79社, 100件 (進捗: 3.4%, 残り約23.9分)
# ページ 1278/2312: 100社, 100件 (進捗: 3.4%, 残り約23.6分)
# ページ 1279/2312: 53社, 100件 (進捗: 3.5%, 残り約23.3分)
# ページ 1280/2312: 100社, 100件 (進捗: 3.5%, 残り約23.0分)
# ページ 1281/2312: 65社, 100件 (進捗: 3.5%, 残り約22.7分)
# バッチ取得: 10 ページ
# ページ 1282/2312: 66社, 100件 (進捗: 3.6%, 残り約28.2分)
# ページ 1283/2312: 58社, 100件 (進捗: 3.6%, 残り約27.8分)
# ページ 1284/2312: 55社, 100件 (進捗: 3.7%, 残り約27.5分)
# ページ 1285/2312: 31社, 100件 (進捗: 3.7%, 残り約27.2分)
# ページ 1286/2312: 49社, 100件 (進捗: 3.8%, 残り約26.8分)
# ページ 1287/2312: 100社, 100件 (進捗: 3.8%, 残り約26.5分)
# ページ 1288/2312: 100社, 100件 (進捗: 3.8%, 残り約26.2分)
# ページ 1289/2312: 91社, 100件 (進捗: 3.9%, 残り約25.9分)
# ページ 1290/2312: 67社, 100件 (進捗: 3.9%, 残り約25.6分)
# ページ 1291/2312: 54社, 100件 (進捗: 4.0%, 残り約25.3分)
# バッチ取得: 10 ページ
# ページ 1292/2312: 52社, 100件 (進捗: 4.0%, 残り約39.6分)
# ページ 1293/2312: 35社, 100件 (進捗: 4.1%, 残り約39.1分)
# ページ 1294/2312: 52社, 100件 (進捗: 4.1%, 残り約38.7分)
# ページ 1295/2312: 52社, 100件 (進捗: 4.2%, 残り約38.3分)
# ページ 1296/2312: 36社, 100件 (進捗: 4.2%, 残り約37.9分)
# ページ 1297/2312: 60社, 100件 (進捗: 4.2%, 残り約37.5分)
# ページ 1298/2312: 83社, 100件 (進捗: 4.3%, 残り約37.1分)
# ページ 1299/2312: 45社, 100件 (進捗: 4.3%, 残り約36.7分)
# ページ 1300/2312: 56社, 100件 (進捗: 4.4%, 残り約36.3分)
# ページ 1301/2312: 69社, 100件 (進捗: 4.4%, 残り約35.9分)
# バッチ取得: 10 ページ
# ページ 1302/2312: 54社, 100件 (進捗: 4.5%, 残り約48.6分)
# ページ 1303/2312: 61社, 100件 (進捗: 4.5%, 残り約48.1分)
# ページ 1304/2312: 56社, 100件 (進捗: 4.5%, 残り約47.6分)
# ページ 1305/2312: 62社, 100件 (進捗: 4.6%, 残り約47.2分)
# ページ 1306/2312: 47社, 100件 (進捗: 4.6%, 残り約46.7分)
# ページ 1307/2312: 58社, 100件 (進捗: 4.7%, 残り約46.2分)
# ページ 1308/2312: 53社, 100件 (進捗: 4.7%, 残り約45.8分)
# ページ 1309/2312: 53社, 100件 (進捗: 4.8%, 残り約45.4分)
# ページ 1310/2312: 32社, 100件 (進捗: 4.8%, 残り約44.9分)
# ページ 1311/2312: 62社, 100件 (進捗: 4.8%, 残り約44.5分)
# バッチ取得: 10 ページ
# ページ 1312/2312: 52社, 100件 (進捗: 4.9%, 残り約56.3分)
# ページ 1313/2312: 62社, 100件 (進捗: 4.9%, 残り約55.8分)
# ページ 1314/2312: 31社, 100件 (進捗: 5.0%, 残り約55.3分)
# ページ 1315/2312: 42社, 100件 (進捗: 5.0%, 残り約54.8分)
# ページ 1316/2312: 51社, 100件 (進捗: 5.1%, 残り約54.3分)
# ページ 1317/2312: 29社, 100件 (進捗: 5.1%, 残り約53.8分)
# ページ 1318/2312: 40社, 100件 (進捗: 5.1%, 残り約53.4分)
# ページ 1319/2312: 30社, 100件 (進捗: 5.2%, 残り約52.9分)
# ページ 1320/2312: 46社, 100件 (進捗: 5.2%, 残り約52.4分)
# ページ 1321/2312: 34社, 100件 (進捗: 5.3%, 残り約52.0分)
# バッチ取得: 10 ページ
# ページ 1322/2312: 30社, 100件 (進捗: 5.3%, 残り約62.5分)
# ページ 1323/2312: 44社, 100件 (進捗: 5.4%, 残り約62.0分)
# ページ 1324/2312: 44社, 100件 (進捗: 5.4%, 残り約61.4分)
# ページ 1325/2312: 70社, 100件 (進捗: 5.4%, 残り約60.9分)
# ページ 1326/2312: 60社, 100件 (進捗: 5.5%, 残り約60.4分)
# ページ 1327/2312: 62社, 100件 (進捗: 5.5%, 残り約59.9分)
# ページ 1328/2312: 88社, 100件 (進捗: 5.6%, 残り約59.4分)
# ページ 1329/2312: 69社, 100件 (進捗: 5.6%, 残り約58.9分)
# ページ 1330/2312: 83社, 100件 (進捗: 5.7%, 残り約58.5分)
# ページ 1331/2312: 88社, 100件 (進捗: 5.7%, 残り約58.0分)
# バッチ取得: 10 ページ
# ページ 1332/2312: 100社, 100件 (進捗: 5.8%, 残り約70.1分)
# ページ 1333/2312: 100社, 100件 (進捗: 5.8%, 残り約69.6分)
# ページ 1334/2312: 98社, 100件 (進捗: 5.8%, 残り約69.0分)
# ページ 1335/2312: 97社, 100件 (進捗: 5.9%, 残り約68.5分)
# ページ 1336/2312: 71社, 100件 (進捗: 5.9%, 残り約68.0分)
# ページ 1337/2312: 96社, 100件 (進捗: 6.0%, 残り約67.5分)
# ページ 1338/2312: 100社, 100件 (進捗: 6.0%, 残り約66.9分)
# ページ 1339/2312: 100社, 100件 (進捗: 6.1%, 残り約66.4分)
# ページ 1340/2312: 100社, 100件 (進捗: 6.1%, 残り約65.9分)
# ページ 1341/2312: 98社, 100件 (進捗: 6.1%, 残り約65.4分)
# バッチ取得: 10 ページ
# ページ 1342/2312: 99社, 100件 (進捗: 6.2%, 残り約75.2分)
# ページ 1343/2312: 97社, 100件 (進捗: 6.2%, 残り約74.6分)
# ページ 1344/2312: 100社, 100件 (進捗: 6.3%, 残り約74.1分)
# ページ 1345/2312: 100社, 100件 (進捗: 6.3%, 残り約73.5分)
# ページ 1346/2312: 100社, 100件 (進捗: 6.4%, 残り約73.0分)
# ページ 1347/2312: 98社, 100件 (進捗: 6.4%, 残り約72.5分)
# ページ 1348/2312: 99社, 100件 (進捗: 6.4%, 残り約72.0分)
# ページ 1349/2312: 99社, 100件 (進捗: 6.5%, 残り約71.5分)
# ページ 1350/2312: 100社, 100件 (進捗: 6.5%, 残り約71.0分)
# ページ 1351/2312: 100社, 100件 (進捗: 6.6%, 残り約70.5分)
# バッチ取得: 10 ページ
# ページ 1352/2312: 100社, 100件 (進捗: 6.6%, 残り約79.5分)
# ページ 1353/2312: 100社, 100件 (進捗: 6.7%, 残り約79.0分)
# ページ 1354/2312: 100社, 100件 (進捗: 6.7%, 残り約78.4分)
# ページ 1355/2312: 100社, 100件 (進捗: 6.7%, 残り約77.9分)
# ページ 1356/2312: 100社, 100件 (進捗: 6.8%, 残り約77.3分)
# ページ 1357/2312: 100社, 100件 (進捗: 6.8%, 残り約76.8分)
# ページ 1358/2312: 100社, 100件 (進捗: 6.9%, 残り約76.3分)
# ページ 1359/2312: 93社, 100件 (進捗: 6.9%, 残り約75.8分)
# ページ 1360/2312: 100社, 100件 (進捗: 7.0%, 残り約75.3分)
# ページ 1361/2312: 100社, 100件 (進捗: 7.0%, 残り約74.8分)
# バッチ取得: 10 ページ
# ページ 1362/2312: 97社, 100件 (進捗: 7.1%, 残り約83.6分)
# ページ 1363/2312: 100社, 100件 (進捗: 7.1%, 残り約83.0分)
# ページ 1364/2312: 100社, 100件 (進捗: 7.1%, 残り約82.5分)
# ページ 1365/2312: 77社, 100件 (進捗: 7.2%, 残り約81.9分)
# ページ 1366/2312: 100社, 100件 (進捗: 7.2%, 残り約81.4分)
# ページ 1367/2312: 100社, 100件 (進捗: 7.3%, 残り約80.9分)
# ページ 1368/2312: 100社, 100件 (進捗: 7.3%, 残り約80.4分)
# ページ 1369/2312: 99社, 100件 (進捗: 7.4%, 残り約79.9分)
# ページ 1370/2312: 100社, 100件 (進捗: 7.4%, 残り約79.4分)
# ページ 1371/2312: 99社, 100件 (進捗: 7.4%, 残り約78.9分)
# バッチ取得: 10 ページ
# ページ 1372/2312: 100社, 100件 (進捗: 7.5%, 残り約86.1分)
# ページ 1373/2312: 100社, 100件 (進捗: 7.5%, 残り約85.6分)
# ページ 1374/2312: 100社, 100件 (進捗: 7.6%, 残り約85.1分)
# ページ 1375/2312: 100社, 100件 (進捗: 7.6%, 残り約84.5分)
# ページ 1376/2312: 100社, 100件 (進捗: 7.7%, 残り約84.0分)
# ページ 1377/2312: 100社, 100件 (進捗: 7.7%, 残り約83.5分)
# ページ 1378/2312: 100社, 100件 (進捗: 7.7%, 残り約83.0分)
# ページ 1379/2312: 100社, 100件 (進捗: 7.8%, 残り約82.5分)
# ページ 1380/2312: 100社, 100件 (進捗: 7.8%, 残り約82.0分)
# ページ 1381/2312: 100社, 100件 (進捗: 7.9%, 残り約81.5分)
# バッチ取得: 10 ページ
# ページ 1382/2312: 100社, 100件 (進捗: 7.9%, 残り約88.3分)
# ページ 1383/2312: 100社, 100件 (進捗: 8.0%, 残り約87.8分)
# ページ 1384/2312: 98社, 100件 (進捗: 8.0%, 残り約87.3分)
# ページ 1385/2312: 100社, 100件 (進捗: 8.0%, 残り約86.8分)
# ページ 1386/2312: 100社, 100件 (進捗: 8.1%, 残り約86.3分)
# ページ 1387/2312: 96社, 100件 (進捗: 8.1%, 残り約85.8分)
# ページ 1388/2312: 99社, 100件 (進捗: 8.2%, 残り約85.3分)
# ページ 1389/2312: 100社, 100件 (進捗: 8.2%, 残り約84.8分)
# ページ 1390/2312: 99社, 100件 (進捗: 8.3%, 残り約84.3分)
# ページ 1391/2312: 100社, 100件 (進捗: 8.3%, 残り約83.8分)
# バッチ取得: 10 ページ
# ページ 1392/2312: 100社, 100件 (進捗: 8.3%, 残り約89.5分)
# ページ 1393/2312: 100社, 100件 (進捗: 8.4%, 残り約89.0分)
# ページ 1394/2312: 100社, 100件 (進捗: 8.4%, 残り約88.5分)
# ページ 1395/2312: 99社, 100件 (進捗: 8.5%, 残り約88.0分)
# ページ 1396/2312: 100社, 100件 (進捗: 8.5%, 残り約87.6分)
# ページ 1397/2312: 100社, 100件 (進捗: 8.6%, 残り約87.1分)
# ページ 1398/2312: 100社, 100件 (進捗: 8.6%, 残り約86.6分)
# ページ 1399/2312: 100社, 100件 (進捗: 8.7%, 残り約86.1分)
# ページ 1400/2312: 100社, 100件 (進捗: 8.7%, 残り約85.7分)
# ページ 1401/2312: 100社, 100件 (進捗: 8.7%, 残り約85.2分)
# バッチ取得: 10 ページ
# ページ 1402/2312: 100社, 100件 (進捗: 8.8%, 残り約90.5分)
# ページ 1403/2312: 100社, 100件 (進捗: 8.8%, 残り約90.1分)
# ページ 1404/2312: 99社, 100件 (進捗: 8.9%, 残り約89.6分)
# ページ 1405/2312: 100社, 100件 (進捗: 8.9%, 残り約89.1分)
# ページ 1406/2312: 100社, 100件 (進捗: 9.0%, 残り約88.6分)
# ページ 1407/2312: 100社, 100件 (進捗: 9.0%, 残り約88.2分)
# ページ 1408/2312: 100社, 100件 (進捗: 9.0%, 残り約87.7分)
# ページ 1409/2312: 100社, 100件 (進捗: 9.1%, 残り約87.2分)
# ページ 1410/2312: 100社, 100件 (進捗: 9.1%, 残り約86.8分)
# ページ 1411/2312: 100社, 100件 (進捗: 9.2%, 残り約86.3分)
# バッチ取得: 10 ページ
# ページ 1412/2312: 100社, 100件 (進捗: 9.2%, 残り約91.6分)
# ページ 1413/2312: 100社, 100件 (進捗: 9.3%, 残り約91.1分)
# ページ 1414/2312: 92社, 100件 (進捗: 9.3%, 残り約90.6分)
# ページ 1415/2312: 100社, 100件 (進捗: 9.3%, 残り約90.2分)
# ページ 1416/2312: 100社, 100件 (進捗: 9.4%, 残り約89.7分)
# ページ 1417/2312: 100社, 100件 (進捗: 9.4%, 残り約89.2分)
# ページ 1418/2312: 100社, 100件 (進捗: 9.5%, 残り約88.8分)
# ページ 1419/2312: 100社, 100件 (進捗: 9.5%, 残り約88.4分)
# ページ 1420/2312: 96社, 100件 (進捗: 9.6%, 残り約87.9分)
# ページ 1421/2312: 100社, 100件 (進捗: 9.6%, 残り約87.5分)
# バッチ取得: 10 ページ
# ページ 1422/2312: 100社, 100件 (進捗: 9.6%, 残り約92.3分)
# ページ 1423/2312: 100社, 100件 (進捗: 9.7%, 残り約91.9分)
# ページ 1424/2312: 100社, 100件 (進捗: 9.7%, 残り約91.4分)
# ページ 1425/2312: 100社, 100件 (進捗: 9.8%, 残り約91.0分)
# ページ 1426/2312: 100社, 100件 (進捗: 9.8%, 残り約90.5分)
# ページ 1427/2312: 100社, 100件 (進捗: 9.9%, 残り約90.1分)
# ページ 1428/2312: 99社, 100件 (進捗: 9.9%, 残り約89.6分)
# ページ 1429/2312: 100社, 100件 (進捗: 9.9%, 残り約89.2分)
# ページ 1430/2312: 100社, 100件 (進捗: 10.0%, 残り約88.8分)
# ページ 1431/2312: 100社, 100件 (進捗: 10.0%, 残り約88.4分)
# バッチ取得: 10 ページ
# ページ 1432/2312: 99社, 100件 (進捗: 10.1%, 残り約93.2分)
# ページ 1433/2312: 100社, 100件 (進捗: 10.1%, 残り約92.8分)
# ページ 1434/2312: 99社, 100件 (進捗: 10.2%, 残り約92.3分)
# ページ 1435/2312: 100社, 100件 (進捗: 10.2%, 残り約91.9分)
# ページ 1436/2312: 95社, 100件 (進捗: 10.3%, 残り約91.5分)
# ページ 1437/2312: 100社, 100件 (進捗: 10.3%, 残り約91.0分)
# ページ 1438/2312: 99社, 100件 (進捗: 10.3%, 残り約90.6分)
# ページ 1439/2312: 100社, 100件 (進捗: 10.4%, 残り約90.2分)
# ページ 1440/2312: 100社, 100件 (進捗: 10.4%, 残り約89.8分)
# ページ 1441/2312: 99社, 100件 (進捗: 10.5%, 残り約89.4分)
# バッチ取得: 10 ページ
# ページ 1442/2312: 100社, 100件 (進捗: 10.5%, 残り約93.7分)
# ページ 1443/2312: 100社, 100件 (進捗: 10.6%, 残り約93.3分)
# ページ 1444/2312: 99社, 100件 (進捗: 10.6%, 残り約92.9分)
# ページ 1445/2312: 96社, 100件 (進捗: 10.6%, 残り約92.5分)
# ページ 1446/2312: 99社, 100件 (進捗: 10.7%, 残り約92.0分)
# ページ 1447/2312: 100社, 100件 (進捗: 10.7%, 残り約91.6分)
# ページ 1448/2312: 94社, 100件 (進捗: 10.8%, 残り約91.2分)
# ページ 1449/2312: 90社, 100件 (進捗: 10.8%, 残り約90.8分)
# ページ 1450/2312: 100社, 100件 (進捗: 10.9%, 残り約90.4分)
# ページ 1451/2312: 100社, 100件 (進捗: 10.9%, 残り約90.0分)
# バッチ取得: 10 ページ
# ページ 1452/2312: 95社, 100件 (進捗: 10.9%, 残り約94.1分)
# ページ 1453/2312: 97社, 100件 (進捗: 11.0%, 残り約93.7分)
# ページ 1454/2312: 92社, 100件 (進捗: 11.0%, 残り約93.3分)
# ページ 1455/2312: 100社, 100件 (進捗: 11.1%, 残り約92.9分)
# ページ 1456/2312: 100社, 100件 (進捗: 11.1%, 残り約92.5分)
# ページ 1457/2312: 98社, 100件 (進捗: 11.2%, 残り約92.1分)
# ページ 1458/2312: 100社, 100件 (進捗: 11.2%, 残り約91.7分)
# ページ 1459/2312: 100社, 100件 (進捗: 11.2%, 残り約91.3分)
# ページ 1460/2312: 92社, 100件 (進捗: 11.3%, 残り約90.9分)
# ページ 1461/2312: 95社, 100件 (進捗: 11.3%, 残り約90.5分)
# バッチ取得: 10 ページ
# ページ 1462/2312: 100社, 100件 (進捗: 11.4%, 残り約95.0分)
# ページ 1463/2312: 100社, 100件 (進捗: 11.4%, 残り約94.6分)
# ページ 1464/2312: 100社, 100件 (進捗: 11.5%, 残り約94.2分)
# ページ 1465/2312: 100社, 100件 (進捗: 11.5%, 残り約93.8分)
# ページ 1466/2312: 96社, 100件 (進捗: 11.5%, 残り約93.4分)
# ページ 1467/2312: 91社, 100件 (進捗: 11.6%, 残り約93.0分)
# ページ 1468/2312: 99社, 100件 (進捗: 11.6%, 残り約92.6分)
# ページ 1469/2312: 100社, 100件 (進捗: 11.7%, 残り約92.2分)
# ページ 1470/2312: 100社, 100件 (進捗: 11.7%, 残り約91.8分)
# ページ 1471/2312: 100社, 100件 (進捗: 11.8%, 残り約91.4分)
# バッチ取得: 10 ページ
# ページ 1472/2312: 100社, 100件 (進捗: 11.8%, 残り約96.1分)
# ページ 1473/2312: 100社, 100件 (進捗: 11.9%, 残り約95.7分)
# ページ 1474/2312: 100社, 100件 (進捗: 11.9%, 残り約95.3分)
# ページ 1475/2312: 99社, 100件 (進捗: 11.9%, 残り約94.9分)
# ページ 1476/2312: 99社, 100件 (進捗: 12.0%, 残り約94.5分)
# ページ 1477/2312: 98社, 100件 (進捗: 12.0%, 残り約94.1分)
# ページ 1478/2312: 98社, 100件 (進捗: 12.1%, 残り約93.7分)
# ページ 1479/2312: 96社, 100件 (進捗: 12.1%, 残り約93.3分)
# ページ 1480/2312: 98社, 100件 (進捗: 12.2%, 残り約93.0分)
# ページ 1481/2312: 97社, 100件 (進捗: 12.2%, 残り約92.6分)
# バッチ取得: 10 ページ
# ページ 1482/2312: 100社, 100件 (進捗: 12.2%, 残り約96.7分)
# ページ 1483/2312: 100社, 100件 (進捗: 12.3%, 残り約96.3分)
# ページ 1484/2312: 100社, 100件 (進捗: 12.3%, 残り約95.9分)
# ページ 1485/2312: 95社, 100件 (進捗: 12.4%, 残り約95.5分)
# ページ 1486/2312: 99社, 100件 (進捗: 12.4%, 残り約95.2分)
# ページ 1487/2312: 97社, 100件 (進捗: 12.5%, 残り約94.8分)
# ページ 1488/2312: 96社, 100件 (進捗: 12.5%, 残り約94.4分)
# ページ 1489/2312: 99社, 100件 (進捗: 12.5%, 残り約94.0分)
# ページ 1490/2312: 100社, 100件 (進捗: 12.6%, 残り約93.7分)
# ページ 1491/2312: 98社, 100件 (進捗: 12.6%, 残り約93.3分)
# バッチ取得: 10 ページ
# ページ 1492/2312: 100社, 100件 (進捗: 12.7%, 残り約96.8分)
# ページ 1493/2312: 100社, 100件 (進捗: 12.7%, 残り約96.4分)
# ページ 1494/2312: 100社, 100件 (進捗: 12.8%, 残り約96.0分)
# ページ 1495/2312: 96社, 100件 (進捗: 12.8%, 残り約95.7分)
# ページ 1496/2312: 99社, 100件 (進捗: 12.8%, 残り約95.3分)
# ページ 1497/2312: 77社, 100件 (進捗: 12.9%, 残り約94.9分)
# ページ 1498/2312: 95社, 100件 (進捗: 12.9%, 残り約94.6分)
# ページ 1499/2312: 95社, 100件 (進捗: 13.0%, 残り約94.2分)
# ページ 1500/2312: 95社, 100件 (進捗: 13.0%, 残り約93.9分)
# ページ 1501/2312: 96社, 100件 (進捗: 13.1%, 残り約93.5分)
# バッチ取得: 10 ページ
# ページ 1502/2312: 80社, 100件 (進捗: 13.1%, 残り約96.9分)
# ページ 1503/2312: 100社, 100件 (進捗: 13.1%, 残り約96.5分)
# ページ 1504/2312: 100社, 100件 (進捗: 13.2%, 残り約96.1分)
# ページ 1505/2312: 96社, 100件 (進捗: 13.2%, 残り約95.8分)
# ページ 1506/2312: 100社, 100件 (進捗: 13.3%, 残り約95.4分)
# ページ 1507/2312: 100社, 100件 (進捗: 13.3%, 残り約95.1分)
# ページ 1508/2312: 100社, 100件 (進捗: 13.4%, 残り約94.7分)
# ページ 1509/2312: 100社, 100件 (進捗: 13.4%, 残り約94.3分)
# ページ 1510/2312: 100社, 100件 (進捗: 13.5%, 残り約94.0分)
# ページ 1511/2312: 100社, 100件 (進捗: 13.5%, 残り約93.7分)
# バッチ取得: 10 ページ
# ページ 1512/2312: 100社, 100件 (進捗: 13.5%, 残り約96.9分)
# ページ 1513/2312: 96社, 100件 (進捗: 13.6%, 残り約96.6分)
# ページ 1514/2312: 93社, 100件 (進捗: 13.6%, 残り約96.2分)
# ページ 1515/2312: 100社, 100件 (進捗: 13.7%, 残り約95.9分)
# ページ 1516/2312: 100社, 100件 (進捗: 13.7%, 残り約95.5分)
# ページ 1517/2312: 100社, 100件 (進捗: 13.8%, 残り約95.2分)
# ページ 1518/2312: 100社, 100件 (進捗: 13.8%, 残り約94.8分)
# ページ 1519/2312: 100社, 100件 (進捗: 13.8%, 残り約94.5分)
# ページ 1520/2312: 100社, 100件 (進捗: 13.9%, 残り約94.1分)
# ページ 1521/2312: 100社, 100件 (進捗: 13.9%, 残り約93.8分)
# バッチ取得: 10 ページ
# ページ 1522/2312: 100社, 100件 (進捗: 14.0%, 残り約97.0分)
# ページ 1523/2312: 100社, 100件 (進捗: 14.0%, 残り約96.6分)
# ページ 1524/2312: 100社, 100件 (進捗: 14.1%, 残り約96.3分)
# ページ 1525/2312: 100社, 100件 (進捗: 14.1%, 残り約95.9分)
# ページ 1526/2312: 100社, 100件 (進捗: 14.1%, 残り約95.6分)
# ページ 1527/2312: 100社, 100件 (進捗: 14.2%, 残り約95.3分)
# ページ 1528/2312: 100社, 100件 (進捗: 14.2%, 残り約94.9分)
# ページ 1529/2312: 100社, 100件 (進捗: 14.3%, 残り約94.6分)
# ページ 1530/2312: 100社, 100件 (進捗: 14.3%, 残り約94.3分)
# ページ 1531/2312: 100社, 100件 (進捗: 14.4%, 残り約93.9分)
# バッチ取得: 10 ページ
# ページ 1532/2312: 100社, 100件 (進捗: 14.4%, 残り約97.0分)
# ページ 1533/2312: 83社, 100件 (進捗: 14.4%, 残り約96.6分)
# ページ 1534/2312: 84社, 100件 (進捗: 14.5%, 残り約96.3分)
# ページ 1535/2312: 81社, 100件 (進捗: 14.5%, 残り約95.9分)
# ページ 1536/2312: 100社, 100件 (進捗: 14.6%, 残り約95.6分)
# ページ 1537/2312: 100社, 100件 (進捗: 14.6%, 残り約95.3分)
# ページ 1538/2312: 100社, 100件 (進捗: 14.7%, 残り約94.9分)
# ページ 1539/2312: 100社, 100件 (進捗: 14.7%, 残り約94.6分)
# ページ 1540/2312: 100社, 100件 (進捗: 14.7%, 残り約94.3分)
# ページ 1541/2312: 94社, 100件 (進捗: 14.8%, 残り約94.0分)
# バッチ取得: 10 ページ
# ページ 1542/2312: 99社, 100件 (進捗: 14.8%, 残り約96.6分)
# ページ 1543/2312: 100社, 100件 (進捗: 14.9%, 残り約96.2分)
# ページ 1544/2312: 100社, 100件 (進捗: 14.9%, 残り約95.9分)
# ページ 1545/2312: 100社, 100件 (進捗: 15.0%, 残り約95.6分)
# ページ 1546/2312: 100社, 100件 (進捗: 15.0%, 残り約95.3分)
# ページ 1547/2312: 100社, 100件 (進捗: 15.1%, 残り約94.9分)
# ページ 1548/2312: 100社, 100件 (進捗: 15.1%, 残り約94.6分)
# ページ 1549/2312: 100社, 100件 (進捗: 15.1%, 残り約94.3分)
# ページ 1550/2312: 100社, 100件 (進捗: 15.2%, 残り約94.0分)
# ページ 1551/2312: 100社, 100件 (進捗: 15.2%, 残り約93.7分)
# バッチ取得: 10 ページ
# ページ 1552/2312: 100社, 100件 (進捗: 15.3%, 残り約96.2分)
# ページ 1553/2312: 100社, 100件 (進捗: 15.3%, 残り約95.9分)
# ページ 1554/2312: 100社, 100件 (進捗: 15.4%, 残り約95.5分)
# ページ 1555/2312: 100社, 100件 (進捗: 15.4%, 残り約95.2分)
# ページ 1556/2312: 100社, 100件 (進捗: 15.4%, 残り約94.9分)
# ページ 1557/2312: 100社, 100件 (進捗: 15.5%, 残り約94.6分)
# ページ 1558/2312: 100社, 100件 (進捗: 15.5%, 残り約94.3分)
# ページ 1559/2312: 100社, 100件 (進捗: 15.6%, 残り約94.0分)
# ページ 1560/2312: 100社, 100件 (進捗: 15.6%, 残り約93.7分)
# ページ 1561/2312: 100社, 100件 (進捗: 15.7%, 残り約93.4分)
# バッチ取得: 10 ページ
# ページ 1562/2312: 100社, 100件 (進捗: 15.7%, 残り約96.0分)
# ページ 1563/2312: 100社, 100件 (進捗: 15.7%, 残り約95.7分)
# ページ 1564/2312: 100社, 100件 (進捗: 15.8%, 残り約95.4分)
# ページ 1565/2312: 86社, 100件 (進捗: 15.8%, 残り約95.0分)
# ページ 1566/2312: 100社, 100件 (進捗: 15.9%, 残り約94.7分)
# ページ 1567/2312: 100社, 100件 (進捗: 15.9%, 残り約94.4分)
# ページ 1568/2312: 100社, 100件 (進捗: 16.0%, 残り約94.1分)
# ページ 1569/2312: 100社, 100件 (進捗: 16.0%, 残り約93.8分)
# ページ 1570/2312: 100社, 100件 (進捗: 16.0%, 残り約93.5分)
# ページ 1571/2312: 100社, 100件 (進捗: 16.1%, 残り約93.2分)
# バッチ取得: 10 ページ
# ページ 1572/2312: 100社, 100件 (進捗: 16.1%, 残り約95.7分)
# ページ 1573/2312: 100社, 100件 (進捗: 16.2%, 残り約95.4分)
# ページ 1574/2312: 100社, 100件 (進捗: 16.2%, 残り約95.1分)
# ページ 1575/2312: 100社, 100件 (進捗: 16.3%, 残り約94.8分)
# ページ 1576/2312: 100社, 100件 (進捗: 16.3%, 残り約94.5分)
# ページ 1577/2312: 99社, 100件 (進捗: 16.3%, 残り約94.2分)
# ページ 1578/2312: 100社, 100件 (進捗: 16.4%, 残り約93.9分)
# ページ 1579/2312: 100社, 100件 (進捗: 16.4%, 残り約93.6分)
# ページ 1580/2312: 100社, 100件 (進捗: 16.5%, 残り約93.3分)
# ページ 1581/2312: 100社, 100件 (進捗: 16.5%, 残り約93.0分)
# バッチ取得: 10 ページ
# ページ 1582/2312: 100社, 100件 (進捗: 16.6%, 残り約95.6分)
# ページ 1583/2312: 99社, 100件 (進捗: 16.6%, 残り約95.3分)
# ページ 1584/2312: 100社, 100件 (進捗: 16.7%, 残り約95.0分)
# ページ 1585/2312: 99社, 100件 (進捗: 16.7%, 残り約94.7分)
# ページ 1586/2312: 97社, 100件 (進捗: 16.7%, 残り約94.5分)
# ページ 1587/2312: 100社, 100件 (進捗: 16.8%, 残り約94.2分)
# ページ 1588/2312: 100社, 100件 (進捗: 16.8%, 残り約93.9分)
# ページ 1589/2312: 100社, 100件 (進捗: 16.9%, 残り約93.6分)
# ページ 1590/2312: 100社, 100件 (進捗: 16.9%, 残り約93.3分)
# ページ 1591/2312: 100社, 100件 (進捗: 17.0%, 残り約93.0分)
# バッチ取得: 10 ページ
# ページ 1592/2312: 100社, 100件 (進捗: 17.0%, 残り約95.3分)
# ページ 1593/2312: 100社, 100件 (進捗: 17.0%, 残り約95.1分)
# ページ 1594/2312: 100社, 100件 (進捗: 17.1%, 残り約94.8分)
# ページ 1595/2312: 100社, 100件 (進捗: 17.1%, 残り約94.5分)
# ページ 1596/2312: 100社, 100件 (進捗: 17.2%, 残り約94.2分)
# ページ 1597/2312: 100社, 100件 (進捗: 17.2%, 残り約93.9分)
# ページ 1598/2312: 100社, 100件 (進捗: 17.3%, 残り約93.6分)
# ページ 1599/2312: 100社, 100件 (進捗: 17.3%, 残り約93.3分)
# ページ 1600/2312: 100社, 100件 (進捗: 17.3%, 残り約93.1分)
# ページ 1601/2312: 100社, 100件 (進捗: 17.4%, 残り約92.8分)
# バッチ取得: 10 ページ
# ページ 1602/2312: 100社, 100件 (進捗: 17.4%, 残り約95.1分)
# ページ 1603/2312: 99社, 100件 (進捗: 17.5%, 残り約94.8分)
# ページ 1604/2312: 95社, 100件 (進捗: 17.5%, 残り約94.5分)
# ページ 1605/2312: 99社, 100件 (進捗: 17.6%, 残り約94.2分)
# ページ 1606/2312: 99社, 100件 (進捗: 17.6%, 残り約93.9分)
# ページ 1607/2312: 100社, 100件 (進捗: 17.6%, 残り約93.6分)
# ページ 1608/2312: 100社, 100件 (進捗: 17.7%, 残り約93.4分)
# ページ 1609/2312: 100社, 100件 (進捗: 17.7%, 残り約93.1分)
# ページ 1610/2312: 100社, 100件 (進捗: 17.8%, 残り約92.8分)
# ページ 1611/2312: 100社, 100件 (進捗: 17.8%, 残り約92.5分)
# バッチ取得: 10 ページ
# ページ 1612/2312: 100社, 100件 (進捗: 17.9%, 残り約94.7分)
# ページ 1613/2312: 100社, 100件 (進捗: 17.9%, 残り約94.5分)
# ページ 1614/2312: 100社, 100件 (進捗: 17.9%, 残り約94.2分)
# ページ 1615/2312: 100社, 100件 (進捗: 18.0%, 残り約93.9分)
# ページ 1616/2312: 100社, 100件 (進捗: 18.0%, 残り約93.6分)
# ページ 1617/2312: 100社, 100件 (進捗: 18.1%, 残り約93.4分)
# ページ 1618/2312: 100社, 100件 (進捗: 18.1%, 残り約93.1分)
# ページ 1619/2312: 100社, 100件 (進捗: 18.2%, 残り約92.8分)
# ページ 1620/2312: 100社, 100件 (進捗: 18.2%, 残り約92.5分)
# ページ 1621/2312: 100社, 100件 (進捗: 18.3%, 残り約92.3分)
# バッチ取得: 10 ページ
# ページ 1622/2312: 99社, 100件 (進捗: 18.3%, 残り約94.6分)
# ページ 1623/2312: 100社, 100件 (進捗: 18.3%, 残り約94.3分)
# ページ 1624/2312: 99社, 100件 (進捗: 18.4%, 残り約94.0分)
# ページ 1625/2312: 100社, 100件 (進捗: 18.4%, 残り約93.7分)
# ページ 1626/2312: 100社, 100件 (進捗: 18.5%, 残り約93.5分)
# ページ 1627/2312: 97社, 100件 (進捗: 18.5%, 残り約93.2分)
# ページ 1628/2312: 100社, 100件 (進捗: 18.6%, 残り約92.9分)
# ページ 1629/2312: 96社, 100件 (進捗: 18.6%, 残り約92.7分)
# ページ 1630/2312: 100社, 100件 (進捗: 18.6%, 残り約92.4分)
# ページ 1631/2312: 100社, 100件 (進捗: 18.7%, 残り約92.1分)
# バッチ取得: 10 ページ
# ページ 1632/2312: 96社, 100件 (進捗: 18.7%, 残り約94.6分)
# ページ 1633/2312: 93社, 100件 (進捗: 18.8%, 残り約94.3分)
# ページ 1634/2312: 99社, 100件 (進捗: 18.8%, 残り約94.0分)
# ページ 1635/2312: 100社, 100件 (進捗: 18.9%, 残り約93.8分)
# ページ 1636/2312: 100社, 100件 (進捗: 18.9%, 残り約93.5分)
# ページ 1637/2312: 99社, 100件 (進捗: 18.9%, 残り約93.2分)
# ページ 1638/2312: 99社, 100件 (進捗: 19.0%, 残り約93.0分)
# ページ 1639/2312: 87社, 100件 (進捗: 19.0%, 残り約92.7分)
# ページ 1640/2312: 97社, 100件 (進捗: 19.1%, 残り約92.4分)
# ページ 1641/2312: 100社, 100件 (進捗: 19.1%, 残り約92.2分)
# バッチ取得: 10 ページ
# ページ 1642/2312: 100社, 100件 (進捗: 19.2%, 残り約94.6分)
# ページ 1643/2312: 96社, 100件 (進捗: 19.2%, 残り約94.4分)
# ページ 1644/2312: 100社, 100件 (進捗: 19.2%, 残り約94.1分)
# ページ 1645/2312: 99社, 100件 (進捗: 19.3%, 残り約93.8分)
# ページ 1646/2312: 100社, 100件 (進捗: 19.3%, 残り約93.6分)
# ページ 1647/2312: 97社, 100件 (進捗: 19.4%, 残り約93.3分)
# ページ 1648/2312: 100社, 100件 (進捗: 19.4%, 残り約93.1分)
# ページ 1649/2312: 100社, 100件 (進捗: 19.5%, 残り約92.8分)
# ページ 1650/2312: 100社, 100件 (進捗: 19.5%, 残り約92.5分)
# ページ 1651/2312: 99社, 100件 (進捗: 19.6%, 残り約92.3分)
# バッチ取得: 10 ページ
# ページ 1652/2312: 100社, 100件 (進捗: 19.6%, 残り約94.6分)
# ページ 1653/2312: 100社, 100件 (進捗: 19.6%, 残り約94.3分)
# ページ 1654/2312: 100社, 100件 (進捗: 19.7%, 残り約94.1分)
# ページ 1655/2312: 99社, 100件 (進捗: 19.7%, 残り約93.8分)
# ページ 1656/2312: 98社, 100件 (進捗: 19.8%, 残り約93.5分)
# ページ 1657/2312: 96社, 100件 (進捗: 19.8%, 残り約93.3分)
# ページ 1658/2312: 96社, 100件 (進捗: 19.9%, 残り約93.0分)
# ページ 1659/2312: 97社, 100件 (進捗: 19.9%, 残り約92.8分)
# ページ 1660/2312: 100社, 100件 (進捗: 19.9%, 残り約92.5分)
# ページ 1661/2312: 100社, 100件 (進捗: 20.0%, 残り約92.3分)
# バッチ取得: 10 ページ
# ページ 1662/2312: 97社, 100件 (進捗: 20.0%, 残り約94.6分)
# ページ 1663/2312: 98社, 100件 (進捗: 20.1%, 残り約94.3分)
# ページ 1664/2312: 100社, 100件 (進捗: 20.1%, 残り約94.1分)
# ページ 1665/2312: 84社, 100件 (進捗: 20.2%, 残り約93.8分)
# ページ 1666/2312: 91社, 100件 (進捗: 20.2%, 残り約93.6分)
# ページ 1667/2312: 87社, 100件 (進捗: 20.2%, 残り約93.3分)
# ページ 1668/2312: 85社, 100件 (進捗: 20.3%, 残り約93.1分)
# ページ 1669/2312: 91社, 100件 (進捗: 20.3%, 残り約92.8分)
# ページ 1670/2312: 85社, 100件 (進捗: 20.4%, 残り約92.6分)
# ページ 1671/2312: 100社, 100件 (進捗: 20.4%, 残り約92.3分)
# バッチ取得: 10 ページ
# ページ 1672/2312: 98社, 100件 (進捗: 20.5%, 残り約94.3分)
# ページ 1673/2312: 88社, 100件 (進捗: 20.5%, 残り約94.0分)
# ページ 1674/2312: 91社, 100件 (進捗: 20.5%, 残り約93.8分)
# ページ 1675/2312: 85社, 100件 (進捗: 20.6%, 残り約93.6分)
# ページ 1676/2312: 95社, 100件 (進捗: 20.6%, 残り約93.3分)
# ページ 1677/2312: 81社, 100件 (進捗: 20.7%, 残り約93.1分)
# ページ 1678/2312: 43社, 100件 (進捗: 20.7%, 残り約92.8分)
# ページ 1679/2312: 38社, 100件 (進捗: 20.8%, 残り約92.6分)
# ページ 1680/2312: 68社, 100件 (進捗: 20.8%, 残り約92.3分)
# ページ 1681/2312: 73社, 100件 (進捗: 20.8%, 残り約92.1分)
# バッチ取得: 10 ページ
# ページ 1682/2312: 52社, 100件 (進捗: 20.9%, 残り約94.0分)
# ページ 1683/2312: 41社, 100件 (進捗: 20.9%, 残り約93.7分)
# ページ 1684/2312: 55社, 100件 (進捗: 21.0%, 残り約93.5分)
# ページ 1685/2312: 54社, 100件 (進捗: 21.0%, 残り約93.2分)
# ページ 1686/2312: 46社, 100件 (進捗: 21.1%, 残り約93.0分)
# ページ 1687/2312: 31社, 100件 (進捗: 21.1%, 残り約92.7分)
# ページ 1688/2312: 49社, 100件 (進捗: 21.2%, 残り約92.5分)
# ページ 1689/2312: 67社, 100件 (進捗: 21.2%, 残り約92.3分)
# ページ 1690/2312: 71社, 100件 (進捗: 21.2%, 残り約92.0分)
# ページ 1691/2312: 46社, 100件 (進捗: 21.3%, 残り約91.8分)
# バッチ取得: 10 ページ
# ページ 1692/2312: 46社, 100件 (進捗: 21.3%, 残り約93.7分)
# ページ 1693/2312: 50社, 100件 (進捗: 21.4%, 残り約93.4分)
# ページ 1694/2312: 26社, 100件 (進捗: 21.4%, 残り約93.2分)
# ページ 1695/2312: 57社, 100件 (進捗: 21.5%, 残り約92.9分)
# ページ 1696/2312: 17社, 100件 (進捗: 21.5%, 残り約92.7分)
# ページ 1697/2312: 35社, 100件 (進捗: 21.5%, 残り約92.5分)
# ページ 1698/2312: 43社, 100件 (進捗: 21.6%, 残り約92.2分)
# ページ 1699/2312: 62社, 100件 (進捗: 21.6%, 残り約92.0分)
# ページ 1700/2312: 39社, 100件 (進捗: 21.7%, 残り約91.8分)
# ページ 1701/2312: 38社, 100件 (進捗: 21.7%, 残り約91.5分)
# バッチ取得: 10 ページ
# ページ 1702/2312: 61社, 100件 (進捗: 21.8%, 残り約93.3分)
# ページ 1703/2312: 43社, 100件 (進捗: 21.8%, 残り約93.1分)
# ページ 1704/2312: 63社, 100件 (進捗: 21.8%, 残り約92.9分)
# ページ 1705/2312: 78社, 100件 (進捗: 21.9%, 残り約92.6分)
# ページ 1706/2312: 68社, 100件 (進捗: 21.9%, 残り約92.4分)
# ページ 1707/2312: 76社, 100件 (進捗: 22.0%, 残り約92.2分)
# ページ 1708/2312: 56社, 100件 (進捗: 22.0%, 残り約91.9分)
# ページ 1709/2312: 58社, 100件 (進捗: 22.1%, 残り約91.7分)
# ページ 1710/2312: 68社, 100件 (進捗: 22.1%, 残り約91.5分)
# ページ 1711/2312: 100社, 100件 (進捗: 22.1%, 残り約91.2分)
# バッチ取得: 10 ページ
# ページ 1712/2312: 95社, 100件 (進捗: 22.2%, 残り約93.0分)
# ページ 1750/2312: 39社, 100件 (進捗: 23.8%, 残り約90.4分)
# ページ 1751/2312: 69社, 100件 (進捗: 23.9%, 残り約90.2分)
# バッチ取得: 10 ページ
# ページ 1752/2312: 96社, 100件 (進捗: 23.9%, 残り約92.0分)
# ページ 1753/2312: 71社, 100件 (進捗: 24.0%, 残り約91.8分)
# ページ 1754/2312: 82社, 100件 (進捗: 24.0%, 残り約91.5分)
# ページ 1755/2312: 97社, 100件 (進捗: 24.0%, 残り約91.3分)
# ページ 1756/2312: 85社, 100件 (進捗: 24.1%, 残り約91.1分)
# ページ 1757/2312: 99社, 100件 (進捗: 24.1%, 残り約90.9分)
# ページ 1758/2312: 72社, 100件 (進捗: 24.2%, 残り約90.7分)
# ページ 1759/2312: 92社, 100件 (進捗: 24.2%, 残り約90.5分)
# ページ 1760/2312: 97社, 100件 (進捗: 24.3%, 残り約90.3分)
# ページ 1761/2312: 77社, 100件 (進捗: 24.3%, 残り約90.0分)
# バッチ取得: 10 ページ
# ページ 1762/2312: 70社, 100件 (進捗: 24.4%, 残り約91.9分)
# ページ 1763/2312: 87社, 100件 (進捗: 24.4%, 残り約91.7分)
# ページ 1764/2312: 85社, 100件 (進捗: 24.4%, 残り約91.5分)
# ページ 1765/2312: 89社, 100件 (進捗: 24.5%, 残り約91.3分)
# ページ 1766/2312: 96社, 100件 (進捗: 24.5%, 残り約91.1分)
# ページ 1767/2312: 100社, 100件 (進捗: 24.6%, 残り約90.8分)
# ページ 1768/2312: 97社, 100件 (進捗: 24.6%, 残り約90.6分)
# ページ 1769/2312: 95社, 100件 (進捗: 24.7%, 残り約90.4分)
# ページ 1770/2312: 100社, 100件 (進捗: 24.7%, 残り約90.2分)
# ページ 1771/2312: 100社, 100件 (進捗: 24.7%, 残り約90.0分)
# バッチ取得: 10 ページ
# ページ 1772/2312: 91社, 100件 (進捗: 24.8%, 残り約91.9分)
# ページ 1773/2312: 97社, 100件 (進捗: 24.8%, 残り約91.6分)
# ページ 1774/2312: 89社, 100件 (進捗: 24.9%, 残り約91.4分)
# ページ 1775/2312: 91社, 100件 (進捗: 24.9%, 残り約91.2分)
# ページ 1776/2312: 63社, 100件 (進捗: 25.0%, 残り約91.0分)
# ページ 1777/2312: 42社, 100件 (進捗: 25.0%, 残り約90.8分)
# ページ 1778/2312: 47社, 100件 (進捗: 25.0%, 残り約90.6分)
# ページ 1779/2312: 48社, 100件 (進捗: 25.1%, 残り約90.4分)
# ページ 1780/2312: 58社, 100件 (進捗: 25.1%, 残り約90.2分)
# ページ 1781/2312: 45社, 100件 (進捗: 25.2%, 残り約90.0分)
# バッチ取得: 10 ページ
# ページ 1782/2312: 55社, 100件 (進捗: 25.2%, 残り約91.6分)
# ページ 1783/2312: 59社, 100件 (進捗: 25.3%, 残り約91.4分)
# ページ 1784/2312: 99社, 100件 (進捗: 25.3%, 残り約91.2分)
# ページ 1785/2312: 100社, 100件 (進捗: 25.3%, 残り約91.0分)
# ページ 1786/2312: 100社, 100件 (進捗: 25.4%, 残り約90.8分)
# ページ 1787/2312: 98社, 100件 (進捗: 25.4%, 残り約90.6分)
# ページ 1788/2312: 98社, 100件 (進捗: 25.5%, 残り約90.4分)
# ページ 1789/2312: 99社, 100件 (進捗: 25.5%, 残り約90.2分)
# ...
# ページ 1987/2312: 96社, 100件 (進捗: 34.0%, 残り約87.0分)
# ページ 1988/2312: 99社, 100件 (進捗: 34.1%, 残り約86.8分)
# ページ 1989/2312: 100社, 100件 (進捗: 34.1%, 残り約86.7分)
# ページ 1990/2312: 97社, 100件 (進捗: 34.2%, 残り約86.5分)
# ページ 1991/2312: 100社, 100件 (進捗: 34.2%, 残り約86.3分)
# バッチ取得: 10 ページ
# ページ 1992/2312: 100社, 100件 (進捗: 34.3%, 残り約87.3分)
# ページ 1993/2312: 100社, 100件 (進捗: 34.3%, 残り約87.1分)
# ページ 1994/2312: 98社, 100件 (進捗: 34.3%, 残り約86.9分)
# ページ 1995/2312: 97社, 100件 (進捗: 34.4%, 残り約86.8分)
# ページ 1996/2312: 99社, 100件 (進捗: 34.4%, 残り約86.6分)
# ページ 1997/2312: 99社, 100件 (進捗: 34.5%, 残り約86.4分)
# ページ 1998/2312: 99社, 100件 (進捗: 34.5%, 残り約86.3分)
# ページ 1999/2312: 100社, 100件 (進捗: 34.6%, 残り約86.1分)
# ページ 2000/2312: 99社, 100件 (進捗: 34.6%, 残り約86.0分)
# ページ 2001/2312: 98社, 100件 (進捗: 34.6%, 残り約85.8分)
# バッチ取得: 10 ページ
# ページ 2002/2312: 100社, 100件 (進捗: 34.7%, 残り約86.9分)
# ページ 2003/2312: 100社, 100件 (進捗: 34.7%, 残り約86.8分)
# ページ 2004/2312: 100社, 100件 (進捗: 34.8%, 残り約86.6分)
# ページ 2005/2312: 100社, 100件 (進捗: 34.8%, 残り約86.4分)
# ページ 2006/2312: 100社, 100件 (進捗: 34.9%, 残り約86.3分)
# ページ 2007/2312: 100社, 100件 (進捗: 34.9%, 残り約86.1分)
# ページ 2008/2312: 100社, 100件 (進捗: 34.9%, 残り約85.9分)
# ページ 2009/2312: 99社, 100件 (進捗: 35.0%, 残り約85.8分)
# ページ 2010/2312: 96社, 100件 (進捗: 35.0%, 残り約85.6分)
# ページ 2011/2312: 100社, 100件 (進捗: 35.1%, 残り約85.5分)
# バッチ取得: 10 ページ
# ページ 2012/2312: 99社, 100件 (進捗: 35.1%, 残り約86.3分)
# ページ 2013/2312: 97社, 100件 (進捗: 35.2%, 残り約86.1分)
# ページ 2014/2312: 94社, 100件 (進捗: 35.2%, 残り約85.9分)
# ページ 2015/2312: 99社, 100件 (進捗: 35.3%, 残り約85.8分)
# ページ 2016/2312: 100社, 100件 (進捗: 35.3%, 残り約85.6分)
# ページ 2017/2312: 100社, 100件 (進捗: 35.3%, 残り約85.5分)
# ページ 2018/2312: 100社, 100件 (進捗: 35.4%, 残り約85.3分)
# ページ 2019/2312: 96社, 100件 (進捗: 35.4%, 残り約85.1分)
# ページ 2020/2312: 99社, 100件 (進捗: 35.5%, 残り約85.0分)
# ページ 2021/2312: 97社, 100件 (進捗: 35.5%, 残り約84.8分)
# バッチ取得: 10 ページ
# ページ 2022/2312: 97社, 100件 (進捗: 35.6%, 残り約85.6分)
# ページ 2023/2312: 99社, 100件 (進捗: 35.6%, 残り約85.5分)
# ページ 2024/2312: 95社, 100件 (進捗: 35.6%, 残り約85.3分)
# ページ 2025/2312: 100社, 100件 (進捗: 35.7%, 残り約85.1分)
# ページ 2026/2312: 96社, 100件 (進捗: 35.7%, 残り約85.0分)
# ページ 2027/2312: 100社, 100件 (進捗: 35.8%, 残り約84.8分)
# ページ 2028/2312: 97社, 100件 (進捗: 35.8%, 残り約84.7分)
# ページ 2029/2312: 99社, 100件 (進捗: 35.9%, 残り約84.5分)
# ページ 2030/2312: 100社, 100件 (進捗: 35.9%, 残り約84.3分)
# ページ 2031/2312: 98社, 100件 (進捗: 35.9%, 残り約84.2分)
# バッチ取得: 10 ページ
# ページ 2032/2312: 98社, 100件 (進捗: 36.0%, 残り約85.0分)
# ページ 2033/2312: 97社, 100件 (進捗: 36.0%, 残り約84.9分)
# ページ 2034/2312: 97社, 100件 (進捗: 36.1%, 残り約84.7分)
# ページ 2035/2312: 99社, 100件 (進捗: 36.1%, 残り約84.5分)
# ページ 2036/2312: 100社, 100件 (進捗: 36.2%, 残り約84.4分)
# ページ 2037/2312: 98社, 100件 (進捗: 36.2%, 残り約84.2分)
# ページ 2038/2312: 98社, 100件 (進捗: 36.2%, 残り約84.1分)
# ページ 2039/2312: 99社, 100件 (進捗: 36.3%, 残り約83.9分)
# ページ 2040/2312: 100社, 100件 (進捗: 36.3%, 残り約83.8分)
# ページ 2041/2312: 98社, 100件 (進捗: 36.4%, 残り約83.6分)
# バッチ取得: 10 ページ
# ページ 2042/2312: 98社, 100件 (進捗: 36.4%, 残り約84.4分)
# ページ 2043/2312: 95社, 100件 (進捗: 36.5%, 残り約84.2分)
# ページ 2044/2312: 96社, 100件 (進捗: 36.5%, 残り約84.1分)
# ページ 2045/2312: 99社, 100件 (進捗: 36.5%, 残り約83.9分)
# ページ 2046/2312: 96社, 100件 (進捗: 36.6%, 残り約83.8分)
# ページ 2047/2312: 98社, 100件 (進捗: 36.6%, 残り約83.6分)
# ページ 2048/2312: 99社, 100件 (進捗: 36.7%, 残り約83.4分)
# ページ 2049/2312: 98社, 100件 (進捗: 36.7%, 残り約83.3分)
# ページ 2050/2312: 98社, 100件 (進捗: 36.8%, 残り約83.1分)
# ページ 2051/2312: 98社, 100件 (進捗: 36.8%, 残り約83.0分)
# バッチ取得: 10 ページ
# ページ 2052/2312: 98社, 100件 (進捗: 36.9%, 残り約83.9分)
# ページ 2053/2312: 96社, 100件 (進捗: 36.9%, 残り約83.7分)
# ページ 2054/2312: 100社, 100件 (進捗: 36.9%, 残り約83.6分)
# ページ 2055/2312: 98社, 100件 (進捗: 37.0%, 残り約83.4分)
# ページ 2056/2312: 100社, 100件 (進捗: 37.0%, 残り約83.3分)
# ページ 2057/2312: 100社, 100件 (進捗: 37.1%, 残り約83.1分)
# ページ 2058/2312: 99社, 100件 (進捗: 37.1%, 残り約83.0分)
# ページ 2059/2312: 100社, 100件 (進捗: 37.2%, 残り約82.8分)
# ページ 2060/2312: 100社, 100件 (進捗: 37.2%, 残り約82.7分)
# ページ 2061/2312: 97社, 100件 (進捗: 37.2%, 残り約82.5分)
# バッチ取得: 10 ページ
# ページ 2062/2312: 92社, 100件 (進捗: 37.3%, 残り約83.3分)
# ページ 2063/2312: 96社, 100件 (進捗: 37.3%, 残り約83.2分)
# ページ 2064/2312: 99社, 100件 (進捗: 37.4%, 残り約83.0分)
# ページ 2065/2312: 99社, 100件 (進捗: 37.4%, 残り約82.8分)
# ページ 2066/2312: 96社, 100件 (進捗: 37.5%, 残り約82.7分)
# ページ 2067/2312: 97社, 100件 (進捗: 37.5%, 残り約82.5分)
# ページ 2068/2312: 99社, 100件 (進捗: 37.5%, 残り約82.4分)
# ページ 2069/2312: 98社, 100件 (進捗: 37.6%, 残り約82.2分)
# ページ 2070/2312: 96社, 100件 (進捗: 37.6%, 残り約82.1分)
# ページ 2071/2312: 99社, 100件 (進捗: 37.7%, 残り約81.9分)
# バッチ取得: 10 ページ
# ページ 2072/2312: 98社, 100件 (進捗: 37.7%, 残り約82.8分)
# ページ 2073/2312: 96社, 100件 (進捗: 37.8%, 残り約82.6分)
# ページ 2074/2312: 99社, 100件 (進捗: 37.8%, 残り約82.5分)
# ページ 2075/2312: 98社, 100件 (進捗: 37.8%, 残り約82.3分)
# ページ 2076/2312: 98社, 100件 (進捗: 37.9%, 残り約82.2分)
# ページ 2077/2312: 99社, 100件 (進捗: 37.9%, 残り約82.0分)
# ページ 2078/2312: 96社, 100件 (進捗: 38.0%, 残り約81.9分)
# ページ 2079/2312: 100社, 100件 (進捗: 38.0%, 残り約81.7分)
# ページ 2080/2312: 99社, 100件 (進捗: 38.1%, 残り約81.6分)
# ページ 2081/2312: 98社, 100件 (進捗: 38.1%, 残り約81.4分)
# バッチ取得: 10 ページ
# ページ 2082/2312: 100社, 100件 (進捗: 38.1%, 残り約82.3分)
# ページ 2083/2312: 95社, 100件 (進捗: 38.2%, 残り約82.1分)
# ページ 2084/2312: 97社, 100件 (進捗: 38.2%, 残り約82.0分)
# ページ 2085/2312: 98社, 100件 (進捗: 38.3%, 残り約81.8分)
# ページ 2086/2312: 99社, 100件 (進捗: 38.3%, 残り約81.7分)
# ページ 2087/2312: 97社, 100件 (進捗: 38.4%, 残り約81.5分)
# ページ 2088/2312: 100社, 100件 (進捗: 38.4%, 残り約81.4分)
# ページ 2089/2312: 100社, 100件 (進捗: 38.5%, 残り約81.2分)
# ページ 2090/2312: 100社, 100件 (進捗: 38.5%, 残り約81.1分)
# ページ 2091/2312: 97社, 100件 (進捗: 38.5%, 残り約80.9分)
# バッチ取得: 10 ページ
# ページ 2092/2312: 98社, 100件 (進捗: 38.6%, 残り約81.7分)
# ページ 2093/2312: 97社, 100件 (進捗: 38.6%, 残り約81.6分)
# ページ 2094/2312: 98社, 100件 (進捗: 38.7%, 残り約81.4分)
# ページ 2095/2312: 99社, 100件 (進捗: 38.7%, 残り約81.3分)
# ページ 2096/2312: 99社, 100件 (進捗: 38.8%, 残り約81.1分)
# ページ 2097/2312: 96社, 100件 (進捗: 38.8%, 残り約81.0分)
# ページ 2098/2312: 100社, 100件 (進捗: 38.8%, 残り約80.8分)
# ページ 2099/2312: 99社, 100件 (進捗: 38.9%, 残り約80.7分)
# ページ 2100/2312: 100社, 100件 (進捗: 38.9%, 残り約80.5分)
# ページ 2101/2312: 100社, 100件 (進捗: 39.0%, 残り約80.4分)
# バッチ取得: 10 ページ
# ページ 2102/2312: 99社, 100件 (進捗: 39.0%, 残り約81.3分)
# ページ 2103/2312: 97社, 100件 (進捗: 39.1%, 残り約81.1分)
# ページ 2104/2312: 95社, 100件 (進捗: 39.1%, 残り約81.0分)
# ページ 2105/2312: 99社, 100件 (進捗: 39.1%, 残り約80.8分)
# ページ 2106/2312: 99社, 100件 (進捗: 39.2%, 残り約80.7分)
# ページ 2107/2312: 98社, 100件 (進捗: 39.2%, 残り約80.5分)
# ページ 2108/2312: 99社, 100件 (進捗: 39.3%, 残り約80.4分)
# ページ 2109/2312: 100社, 100件 (進捗: 39.3%, 残り約80.2分)
# ページ 2110/2312: 100社, 100件 (進捗: 39.4%, 残り約80.1分)
# ページ 2111/2312: 98社, 100件 (進捗: 39.4%, 残り約80.0分)
# バッチ取得: 10 ページ
# ページ 2112/2312: 98社, 100件 (進捗: 39.4%, 残り約80.7分)
# ページ 2113/2312: 99社, 100件 (進捗: 39.5%, 残り約80.6分)
# ページ 2114/2312: 98社, 100件 (進捗: 39.5%, 残り約80.4分)
# ページ 2115/2312: 98社, 100件 (進捗: 39.6%, 残り約80.3分)
# ページ 2116/2312: 99社, 100件 (進捗: 39.6%, 残り約80.1分)
# ページ 2117/2312: 100社, 100件 (進捗: 39.7%, 残り約80.0分)
# ページ 2118/2312: 99社, 100件 (進捗: 39.7%, 残り約79.9分)
# ページ 2119/2312: 100社, 100件 (進捗: 39.7%, 残り約79.7分)
# ページ 2120/2312: 100社, 100件 (進捗: 39.8%, 残り約79.6分)
# ページ 2121/2312: 97社, 100件 (進捗: 39.8%, 残り約79.4分)
# バッチ取得: 10 ページ
# ページ 2122/2312: 100社, 100件 (進捗: 39.9%, 残り約80.6分)
# ページ 2123/2312: 99社, 100件 (進捗: 39.9%, 残り約80.5分)
# ページ 2124/2312: 98社, 100件 (進捗: 40.0%, 残り約80.4分)
# ページ 2125/2312: 97社, 100件 (進捗: 40.0%, 残り約80.2分)
# ページ 2126/2312: 100社, 100件 (進捗: 40.1%, 残り約80.1分)
# ページ 2127/2312: 98社, 100件 (進捗: 40.1%, 残り約79.9分)
# ページ 2128/2312: 100社, 100件 (進捗: 40.1%, 残り約79.8分)
# ページ 2129/2312: 99社, 100件 (進捗: 40.2%, 残り約79.6分)
# ページ 2130/2312: 99社, 100件 (進捗: 40.2%, 残り約79.5分)
# ページ 2131/2312: 100社, 100件 (進捗: 40.3%, 残り約79.4分)
# バッチ取得: 10 ページ
# ページ 2132/2312: 99社, 100件 (進捗: 40.3%, 残り約80.2分)
# ページ 2133/2312: 95社, 100件 (進捗: 40.4%, 残り約80.1分)
# ページ 2134/2312: 97社, 100件 (進捗: 40.4%, 残り約79.9分)
# ページ 2135/2312: 100社, 100件 (進捗: 40.4%, 残り約79.8分)
# ページ 2136/2312: 99社, 100件 (進捗: 40.5%, 残り約79.6分)
# ページ 2137/2312: 99社, 100件 (進捗: 40.5%, 残り約79.5分)
# ページ 2138/2312: 98社, 100件 (進捗: 40.6%, 残り約79.4分)
# ページ 2139/2312: 98社, 100件 (進捗: 40.6%, 残り約79.2分)
# ページ 2140/2312: 100社, 100件 (進捗: 40.7%, 残り約79.1分)
# ページ 2141/2312: 99社, 100件 (進捗: 40.7%, 残り約78.9分)
# バッチ取得: 10 ページ
# ページ 2142/2312: 99社, 100件 (進捗: 40.7%, 残り約79.7分)
# ページ 2143/2312: 99社, 100件 (進捗: 40.8%, 残り約79.5分)
# ページ 2144/2312: 100社, 100件 (進捗: 40.8%, 残り約79.4分)
# ページ 2145/2312: 100社, 100件 (進捗: 40.9%, 残り約79.3分)
# ページ 2146/2312: 92社, 100件 (進捗: 40.9%, 残り約79.1分)
# ページ 2147/2312: 96社, 100件 (進捗: 41.0%, 残り約79.0分)
# ページ 2148/2312: 99社, 100件 (進捗: 41.0%, 残り約78.8分)
# ページ 2149/2312: 99社, 100件 (進捗: 41.0%, 残り約78.7分)
# ページ 2150/2312: 95社, 100件 (進捗: 41.1%, 残り約78.5分)
# ページ 2151/2312: 100社, 100件 (進捗: 41.1%, 残り約78.4分)
# バッチ取得: 10 ページ
# ページ 2152/2312: 82社, 100件 (進捗: 41.2%, 残り約79.1分)
# ページ 2153/2312: 95社, 100件 (進捗: 41.2%, 残り約79.0分)
# ページ 2154/2312: 97社, 100件 (進捗: 41.3%, 残り約78.8分)
# ページ 2155/2312: 98社, 100件 (進捗: 41.3%, 残り約78.7分)
# ページ 2156/2312: 92社, 100件 (進捗: 41.3%, 残り約78.6分)
# ページ 2157/2312: 92社, 100件 (進捗: 41.4%, 残り約78.4分)
# ページ 2158/2312: 98社, 100件 (進捗: 41.4%, 残り約78.3分)
# ページ 2159/2312: 92社, 100件 (進捗: 41.5%, 残り約78.1分)
# ページ 2160/2312: 95社, 100件 (進捗: 41.5%, 残り約78.0分)
# ページ 2161/2312: 97社, 100件 (進捗: 41.6%, 残り約77.9分)
# バッチ取得: 10 ページ
# ページ 2162/2312: 90社, 100件 (進捗: 41.6%, 残り約78.6分)
# ページ 2163/2312: 98社, 100件 (進捗: 41.7%, 残り約78.4分)
# ページ 2164/2312: 100社, 100件 (進捗: 41.7%, 残り約78.3分)
# ページ 2165/2312: 95社, 100件 (進捗: 41.7%, 残り約78.1分)
# ページ 2166/2312: 99社, 100件 (進捗: 41.8%, 残り約78.0分)
# ページ 2167/2312: 98社, 100件 (進捗: 41.8%, 残り約77.9分)
# ページ 2168/2312: 90社, 100件 (進捗: 41.9%, 残り約77.7分)
# ページ 2169/2312: 99社, 100件 (進捗: 41.9%, 残り約77.6分)
# ページ 2170/2312: 97社, 100件 (進捗: 42.0%, 残り約77.5分)
# ページ 2171/2312: 99社, 100件 (進捗: 42.0%, 残り約77.3分)
# バッチ取得: 10 ページ
# ページ 2172/2312: 88社, 100件 (進捗: 42.0%, 残り約78.0分)
# ページ 2173/2312: 78社, 100件 (進捗: 42.1%, 残り約77.9分)
# ページ 2174/2312: 79社, 100件 (進捗: 42.1%, 残り約77.7分)
# ページ 2175/2312: 89社, 100件 (進捗: 42.2%, 残り約77.6分)
# ページ 2176/2312: 84社, 100件 (進捗: 42.2%, 残り約77.5分)
# ページ 2177/2312: 86社, 100件 (進捗: 42.3%, 残り約77.3分)
# ページ 2178/2312: 99社, 100件 (進捗: 42.3%, 残り約77.2分)
# ページ 2179/2312: 100社, 100件 (進捗: 42.3%, 残り約77.0分)
# ページ 2180/2312: 100社, 100件 (進捗: 42.4%, 残り約76.9分)
# ページ 2181/2312: 97社, 100件 (進捗: 42.4%, 残り約76.8分)
# バッチ取得: 10 ページ
# ページ 2182/2312: 100社, 100件 (進捗: 42.5%, 残り約77.4分)
# ページ 2183/2312: 100社, 100件 (進捗: 42.5%, 残り約77.3分)
# ページ 2184/2312: 99社, 100件 (進捗: 42.6%, 残り約77.2分)
# ページ 2185/2312: 100社, 100件 (進捗: 42.6%, 残り約77.0分)
# ページ 2186/2312: 98社, 100件 (進捗: 42.6%, 残り約76.9分)
# ページ 2187/2312: 100社, 100件 (進捗: 42.7%, 残り約76.8分)
# ページ 2188/2312: 99社, 100件 (進捗: 42.7%, 残り約76.6分)
# ページ 2189/2312: 99社, 100件 (進捗: 42.8%, 残り約76.5分)
# ページ 2190/2312: 100社, 100件 (進捗: 42.8%, 残り約76.4分)
# ページ 2191/2312: 100社, 100件 (進捗: 42.9%, 残り約76.2分)
# バッチ取得: 10 ページ
# ページ 2192/2312: 100社, 100件 (進捗: 42.9%, 残り約76.9分)
# ページ 2193/2312: 99社, 100件 (進捗: 42.9%, 残り約76.7分)
# ページ 2194/2312: 99社, 100件 (進捗: 43.0%, 残り約76.6分)
# ページ 2195/2312: 99社, 100件 (進捗: 43.0%, 残り約76.5分)
# ページ 2196/2312: 95社, 100件 (進捗: 43.1%, 残り約76.3分)
# ページ 2197/2312: 90社, 100件 (進捗: 43.1%, 残り約76.2分)
# ページ 2198/2312: 87社, 100件 (進捗: 43.2%, 残り約76.1分)
# ページ 2199/2312: 87社, 100件 (進捗: 43.2%, 残り約75.9分)
# ページ 2200/2312: 93社, 100件 (進捗: 43.3%, 残り約75.8分)
# ページ 2201/2312: 92社, 100件 (進捗: 43.3%, 残り約75.7分)
# バッチ取得: 10 ページ
# ページ 2202/2312: 91社, 100件 (進捗: 43.3%, 残り約76.4分)
# ページ 2203/2312: 90社, 100件 (進捗: 43.4%, 残り約76.3分)
# ページ 2204/2312: 94社, 100件 (進捗: 43.4%, 残り約76.1分)
# ページ 2205/2312: 85社, 100件 (進捗: 43.5%, 残り約76.0分)
# ページ 2206/2312: 92社, 100件 (進捗: 43.5%, 残り約75.9分)
# ページ 2207/2312: 98社, 100件 (進捗: 43.6%, 残り約75.7分)
# ページ 2208/2312: 64社, 100件 (進捗: 43.6%, 残り約75.6分)
# ページ 2209/2312: 90社, 100件 (進捗: 43.6%, 残り約75.5分)
# ページ 2210/2312: 90社, 100件 (進捗: 43.7%, 残り約75.3分)
# ページ 2211/2312: 94社, 100件 (進捗: 43.7%, 残り約75.2分)
# バッチ取得: 10 ページ
# ページ 2212/2312: 85社, 100件 (進捗: 43.8%, 残り約75.9分)
# ページ 2213/2312: 93社, 100件 (進捗: 43.8%, 残り約75.8分)
# ページ 2214/2312: 99社, 100件 (進捗: 43.9%, 残り約75.6分)
# ページ 2215/2312: 100社, 100件 (進捗: 43.9%, 残り約75.5分)
# ページ 2216/2312: 100社, 100件 (進捗: 43.9%, 残り約75.4分)
# ページ 2217/2312: 100社, 100件 (進捗: 44.0%, 残り約75.2分)
# ページ 2218/2312: 100社, 100件 (進捗: 44.0%, 残り約75.1分)
# ページ 2219/2312: 100社, 100件 (進捗: 44.1%, 残り約75.0分)
# ページ 2220/2312: 100社, 100件 (進捗: 44.1%, 残り約74.8分)
# ページ 2221/2312: 100社, 100件 (進捗: 44.2%, 残り約74.7分)
# バッチ取得: 10 ページ
# ページ 2222/2312: 100社, 100件 (進捗: 44.2%, 残り約75.5分)
# ページ 2223/2312: 97社, 100件 (進捗: 44.2%, 残り約75.4分)
# ページ 2224/2312: 92社, 100件 (進捗: 44.3%, 残り約75.2分)
# ページ 2225/2312: 84社, 100件 (進捗: 44.3%, 残り約75.1分)
# ページ 2226/2312: 96社, 100件 (進捗: 44.4%, 残り約75.0分)
# ページ 2227/2312: 88社, 100件 (進捗: 44.4%, 残り約74.8分)
# ページ 2228/2312: 79社, 100件 (進捗: 44.5%, 残り約74.7分)
# ページ 2229/2312: 81社, 100件 (進捗: 44.5%, 残り約74.6分)
# ページ 2230/2312: 98社, 100件 (進捗: 44.6%, 残り約74.4分)
# ページ 2231/2312: 99社, 100件 (進捗: 44.6%, 残り約74.3分)
# バッチ取得: 10 ページ
# ページ 2232/2312: 100社, 100件 (進捗: 44.6%, 残り約75.0分)
# ページ 2233/2312: 100社, 100件 (進捗: 44.7%, 残り約74.9分)
# ページ 2234/2312: 99社, 100件 (進捗: 44.7%, 残り約74.8分)
# ページ 2235/2312: 100社, 100件 (進捗: 44.8%, 残り約74.6分)
# ページ 2236/2312: 100社, 100件 (進捗: 44.8%, 残り約74.5分)
# ページ 2237/2312: 100社, 100件 (進捗: 44.9%, 残り約74.4分)
# ページ 2238/2312: 100社, 100件 (進捗: 44.9%, 残り約74.2分)
# ページ 2239/2312: 100社, 100件 (進捗: 44.9%, 残り約74.1分)
# ページ 2240/2312: 100社, 100件 (進捗: 45.0%, 残り約74.0分)
# ページ 2241/2312: 100社, 100件 (進捗: 45.0%, 残り約73.8分)
# バッチ取得: 10 ページ
# ページ 2242/2312: 100社, 100件 (進捗: 45.1%, 残り約74.5分)
# ページ 2243/2312: 100社, 100件 (進捗: 45.1%, 残り約74.4分)
# ページ 2244/2312: 100社, 100件 (進捗: 45.2%, 残り約74.3分)
# ページ 2245/2312: 100社, 100件 (進捗: 45.2%, 残り約74.1分)
# ページ 2246/2312: 100社, 100件 (進捗: 45.2%, 残り約74.0分)
# ページ 2247/2312: 100社, 100件 (進捗: 45.3%, 残り約73.9分)
# ページ 2248/2312: 99社, 100件 (進捗: 45.3%, 残り約73.7分)
# ページ 2249/2312: 100社, 100件 (進捗: 45.4%, 残り約73.6分)
# ページ 2250/2312: 100社, 100件 (進捗: 45.4%, 残り約73.5分)
# ページ 2251/2312: 100社, 100件 (進捗: 45.5%, 残り約73.4分)
# バッチ取得: 10 ページ
# ページ 2252/2312: 100社, 100件 (進捗: 45.5%, 残り約74.0分)
# ページ 2253/2312: 100社, 100件 (進捗: 45.5%, 残り約73.9分)
# ページ 2254/2312: 100社, 100件 (進捗: 45.6%, 残り約73.8分)
# ページ 2255/2312: 100社, 100件 (進捗: 45.6%, 残り約73.6分)
# ページ 2256/2312: 100社, 100件 (進捗: 45.7%, 残り約73.5分)
# ページ 2257/2312: 100社, 100件 (進捗: 45.7%, 残り約73.4分)
# ページ 2258/2312: 100社, 100件 (進捗: 45.8%, 残り約73.2分)
# ページ 2259/2312: 100社, 100件 (進捗: 45.8%, 残り約73.1分)
# ページ 2260/2312: 100社, 100件 (進捗: 45.8%, 残り約73.0分)
# ページ 2261/2312: 100社, 100件 (進捗: 45.9%, 残り約72.9分)
# バッチ取得: 10 ページ
# ページ 2262/2312: 99社, 100件 (進捗: 45.9%, 残り約73.5分)
# ページ 2263/2312: 100社, 100件 (進捗: 46.0%, 残り約73.4分)
# ページ 2264/2312: 100社, 100件 (進捗: 46.0%, 残り約73.3分)
# ページ 2265/2312: 100社, 100件 (進捗: 46.1%, 残り約73.1分)
# ページ 2266/2312: 100社, 100件 (進捗: 46.1%, 残り約73.0分)
# ページ 2267/2312: 100社, 100件 (進捗: 46.2%, 残り約72.9分)
# ページ 2268/2312: 100社, 100件 (進捗: 46.2%, 残り約72.8分)
# ページ 2269/2312: 100社, 100件 (進捗: 46.2%, 残り約72.6分)
# ページ 2270/2312: 100社, 100件 (進捗: 46.3%, 残り約72.5分)
# ページ 2271/2312: 100社, 100件 (進捗: 46.3%, 残り約72.4分)
# バッチ取得: 10 ページ
# ページ 2272/2312: 100社, 100件 (進捗: 46.4%, 残り約73.0分)
# ページ 2273/2312: 100社, 100件 (進捗: 46.4%, 残り約72.9分)
# ページ 2274/2312: 100社, 100件 (進捗: 46.5%, 残り約72.8分)
# ページ 2275/2312: 100社, 100件 (進捗: 46.5%, 残り約72.6分)
# ページ 2276/2312: 100社, 100件 (進捗: 46.5%, 残り約72.5分)
# ページ 2277/2312: 100社, 100件 (進捗: 46.6%, 残り約72.4分)
# ページ 2278/2312: 100社, 100件 (進捗: 46.6%, 残り約72.2分)
# ページ 2279/2312: 100社, 100件 (進捗: 46.7%, 残り約72.1分)
# ページ 2280/2312: 100社, 100件 (進捗: 46.7%, 残り約72.0分)
# ページ 2281/2312: 100社, 100件 (進捗: 46.8%, 残り約71.9分)
# バッチ取得: 10 ページ
# ページ 2282/2312: 100社, 100件 (進捗: 46.8%, 残り約72.6分)
# ページ 2283/2312: 100社, 100件 (進捗: 46.8%, 残り約72.5分)
# ページ 2284/2312: 100社, 100件 (進捗: 46.9%, 残り約72.3分)
# ページ 2285/2312: 100社, 100件 (進捗: 46.9%, 残り約72.2分)
# ページ 2286/2312: 100社, 100件 (進捗: 47.0%, 残り約72.1分)
# ページ 2287/2312: 100社, 100件 (進捗: 47.0%, 残り約72.0分)
# ページ 2288/2312: 100社, 100件 (進捗: 47.1%, 残り約71.8分)
# ページ 2289/2312: 100社, 100件 (進捗: 47.1%, 残り約71.7分)
# ページ 2290/2312: 100社, 100件 (進捗: 47.1%, 残り約71.6分)
# ページ 2291/2312: 100社, 100件 (進捗: 47.2%, 残り約71.5分)
# バッチ取得: 10 ページ
# ページ 2292/2312: 100社, 100件 (進捗: 47.2%, 残り約72.1分)
# ページ 2293/2312: 99社, 100件 (進捗: 47.3%, 残り約72.0分)
# ページ 2294/2312: 97社, 100件 (進捗: 47.3%, 残り約71.8分)
# ページ 2295/2312: 85社, 100件 (進捗: 47.4%, 残り約71.7分)
# ページ 2296/2312: 80社, 100件 (進捗: 47.4%, 残り約71.6分)
# ページ 2297/2312: 77社, 100件 (進捗: 47.4%, 残り約71.5分)
# ページ 2298/2312: 55社, 100件 (進捗: 47.5%, 残り約71.4分)
# ページ 2299/2312: 49社, 100件 (進捗: 47.5%, 残り約71.2分)
# ページ 2300/2312: 80社, 100件 (進捗: 47.6%, 残り約71.1分)
# ページ 2301/2312: 73社, 100件 (進捗: 47.6%, 残り約71.0分)
# バッチ取得: 10 ページ
# ページ 2302/2312: 68社, 100件 (進捗: 47.7%, 残り約71.6分)
# ページ 2303/2312: 75社, 100件 (進捗: 47.7%, 残り約71.5分)
# ページ 2304/2312: 93社, 100件 (進捗: 47.8%, 残り約71.4分)
# ページ 2305/2312: 55社, 100件 (進捗: 47.8%, 残り約71.2分)
# ページ 2306/2312: 85社, 100件 (進捗: 47.8%, 残り約71.1分)
# ページ 2307/2312: 67社, 100件 (進捗: 47.9%, 残り約71.0分)
# ページ 2308/2312: 74社, 100件 (進捗: 47.9%, 残り約70.9分)
# ページ 2309/2312: 54社, 100件 (進捗: 48.0%, 残り約70.7分)
# ページ 2310/2312: 55社, 100件 (進捗: 48.0%, 残り約70.6分)
# ページ 2311/2312: 86社, 100件 (進捗: 48.1%, 残り約70.5分)
# バッチ取得: 1 ページ
# ページ 2312/2312: 6社, 7件 (進捗: 48.1%, 残り約70.6分)
#
# 処理完了 (65.4分): 2023年度データ
# データベースには91245社の法人情報と231007件の補助金情報があります
